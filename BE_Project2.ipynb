# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Permanent Data Merging - **Do not change**

# %%
# %%script false --no-raise-error
# ds_inital = 'https://github.com/koushal2001/procurement_timeframe/blob/main/studentproject_arde_DATA.xlsx?raw=true'
# ds_asl = 'https://github.com/koushal2001/procurement_timeframe/blob/main/ASL_Data_2021-22.xlsx?raw=true'
# ds_drdl = 'https://github.com/koushal2001/procurement_timeframe/blob/main/DRDL_Data_2021-22.xlsx?raw=true'
# ds_hemrl = 'https://github.com/koushal2001/procurement_timeframe/blob/main/HEMRL_Data_2021-22.xlsx?raw=true'
# ds_rci = 'https://github.com/koushal2001/procurement_timeframe/blob/main/RCI_Data_2021-22.xlsx?raw=true'

# %%
# %%script false --no-raise-error
# df_initial = pd.read_excel(ds_inital, sheet_name='Export Worksheet')
# df_asl = pd.read_excel(ds_asl, sheet_name='ASL_Data_2021-22')
# df_drdl = pd.read_excel(ds_drdl, sheet_name='DRDL_Data_2021-22')
# df_hemrl = pd.read_excel(ds_hemrl, sheet_name='HEMRL_Data_2021-22')
# df_rci = pd.read_excel(ds_rci, sheet_name='RCI_Data_2021-22')
# Out:
# /usr/local/lib/python3.8/dist-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
# %%script false --no-raise-error
# df_asl = df_asl.drop(df_asl.columns.difference(df_initial.columns).to_list(), axis=1)
# df_drdl = df_drdl.drop(df_drdl.columns.difference(df_initial.columns).to_list(), axis=1)
# df_hemrl = df_hemrl.drop(df_hemrl.columns.difference(df_initial.columns).to_list(), axis=1)
# df_rci = df_rci.drop(df_rci.columns.difference(df_initial.columns).to_list(), axis=1)
# df = pd.concat([df_initial, df_asl, df_drdl, df_hemrl, df_rci])

# %%
# %%script false --no-raise-error
# df.to_excel('dataset.xlsx', index=False)

# %% [markdown]
# # Continued

# %%
filepath = 'https://github.com/koushal2001/procurement_timeframe/blob/main/dataset.xlsx?raw=true'
# filepath = '/content/drive/MyDrive/studentproject_arde_DATA.xlsx'
df = pd.read_excel(filepath, sheet_name='Sheet1')
df.head()
# Out:
#   SUPPLY_ORDER_NO    SUPPLY_ORDER_DATE  TOTAL_COST MODE_OF_TENDER_CODE  \
# 0        22SO0001  2021-04-05 16:20:08   119650.23                  lp
# 1        22GM0001  2021-04-06 00:00:00   209600.00                  GM
# 2        22GM0007  2021-04-06 00:00:00     2100.00                  GM
# 3        22GM0008  2021-04-06 00:00:00    26800.00                  GM
# 4        22GM0002  2021-04-06 00:00:00     7978.00                  GM
#
#               MODEOFTENDER PROCUREMENT_MODE_CODE    PROCUREMENT_MODE_DESC  \
# 0              Through LPC                    SO      Supply orders  (SO)
# 1  Procurement Through GeM                    GM  Procurement through GeM
# 2  Procurement Through GeM                    GM  Procurement through GeM
# 3  Procurement Through GeM                    GM  Procurement through GeM
# 4  Procurement Through GeM                    GM  Procurement through GeM
#
#   DEMAND_NO    RFP_NO  FINANCIAL_POWER_CODE  ... BUDGET_HEAD_DESCRIPTION_1  \
# ...

# %%
cols = df.columns.tolist()
cols
# Out:
# ['SUPPLY_ORDER_NO',
#  'SUPPLY_ORDER_DATE',
#  'TOTAL_COST',
#  'MODE_OF_TENDER_CODE',
#  'MODEOFTENDER',
#  'PROCUREMENT_MODE_CODE',
#  'PROCUREMENT_MODE_DESC',
#  'DEMAND_NO',
#  'RFP_NO',
#  'FINANCIAL_POWER_CODE',
#  'FINANCIAL_POWER_SERIAL_NO',
#  'CFA_CODE',
#  'CFA_DESCRIPTION',
#  'SANCTION_DATE',
#  'CONCURRENCE_LEVEL_CODE',
#  'CONCURRED_BY',
#  'UO_NO',
#  'CONCURRENCE_DATE',
#  'GEM_CONTRACT_NO',
#  'GEM_CONTRACT_DATE',
#  'BUDGET_HEAD_CODE',
#  'BUDGET_HEAD_DESCRIPTION',
#  'AGAINST_SANCTION_NO',
#  'MAJOR_HEAD',
#  'SUB_MAJOR_HEAD',
#  'MINOR_HEAD',
#  'HEAD_CODE',
#  'UNITCODE',
#  'UNITCODE_DESCRIPTION',
#  'RECEIPT_DETAILS',
#  'DEMAND_NO_1',
#  'DEMAND_DATE',
#  'ESTIMATED_COST',
#  'DIVISION_NO',
#  'DIVISION_NAME',
#  'FIN_POWER',
#  'FIN_POWER_DEMAND_FS',
#  'METHOD_OF_PURCHASE',
#  'BUDGET_HEAD_DESCRIPTION_1',
#  'PROCUREMENT_MODE_DESC_1',
#  'IS_PAC',
#  'CONCURRENCE_BY',
#  'CONCURRENCE_DATE_1',
#  'CONCURRENCE_AMOUNT',
#  'CFA',
#  'CFA_APPROVAL_REFERENCE',
# ...

# %%
df.isnull().sum()
# Out:
# SUPPLY_ORDER_NO                 0
# SUPPLY_ORDER_DATE               0
# TOTAL_COST                      0
# MODE_OF_TENDER_CODE             0
# MODEOFTENDER                    0
# PROCUREMENT_MODE_CODE           0
# PROCUREMENT_MODE_DESC           0
# DEMAND_NO                       0
# RFP_NO                       1422
# FINANCIAL_POWER_CODE            0
# FINANCIAL_POWER_SERIAL_NO       0
# CFA_CODE                      100
# CFA_DESCRIPTION               100
# SANCTION_DATE                 100
# CONCURRENCE_LEVEL_CODE       3996
# CONCURRED_BY                 3996
# UO_NO                        3996
# CONCURRENCE_DATE             3996
# GEM_CONTRACT_NO              2279
# GEM_CONTRACT_DATE            2279
# BUDGET_HEAD_CODE                0
# BUDGET_HEAD_DESCRIPTION         0
# AGAINST_SANCTION_NO          2056
# MAJOR_HEAD                      0
# SUB_MAJOR_HEAD               4152
# MINOR_HEAD                      0
# HEAD_CODE                       0
# ...

# %%
date_cols = ['SUPPLY_ORDER_DATE', 'SANCTION_DATE', 'CONCURRENCE_DATE', 'GEM_CONTRACT_DATE', 'DEMAND_DATE', 'CONCURRENCE_DATE_1', 'CFA_APPROVAL_DATE']
for col in date_cols:
  df[col] = pd.to_datetime(df[col])

# %%
df['TOTAL_DAYS'] = (df['SUPPLY_ORDER_DATE'] - df['DEMAND_DATE']).dt.days

# %%
df['TOTAL_DAYS']
# Out:
# 0        33
# 1        39
# 2        19
# 3        17
# 4        13
#        ...
# 4147    186
# 4148    139
# 4149     98
# 4150    157
# 4151    160
# Name: TOTAL_DAYS, Length: 4152, dtype: int64

# %%
def range_encoding(df, source_col_name, dest_col_name, ranges, encoding):
  ranges_result = []
  for val in df[source_col_name]:
    flag = False
    for i in range(len(encoding) - 1):
      if ranges[i][0] <= val <= ranges[i][1]:
        ranges_result.append(encoding[i])
        flag = True
        break
    if not flag:
      ranges_result.append(encoding[len(encoding) - 1])

  df[dest_col_name] = ranges_result
  return df

# %%
df['ESTIMATED_COST']
# Out:
# 0       119650
# 1       212478
# 2         2200
# 3        26800
# 4         7978
#          ...
# 4147    799998
# 4148    142480
# 4149    497252
# 4150     61999
# 4151     68500
# Name: ESTIMATED_COST, Length: 4152, dtype: int64

# %%
day_ranges = [(0, 60), (61, 90), (91, 120), (121, 150), (151, 180)]
day_ranges_encoding = ['0 - 60', '60 - 90', '90 - 120', '120 - 150', '150 - 180', '> 180']

df = range_encoding(df, 'TOTAL_DAYS', 'TOTAL_DAYS_RANGES', day_ranges, day_ranges_encoding)

# %%
cost_ranges = [(0, 1000000), (1000001, 2500000), (2500001, 5000000), (5000001, 10000000), (10000001, 50000000), (50000001, 100000000)]
cost_ranges_endcoding = ['0 - 10L', '10L - 25L', '25L - 50L', '50L - 1CR', '1CR - 5CR', '5CR - 10CR', '> 10CR']

df = range_encoding(df, 'ESTIMATED_COST', 'EST_COST_RANGE', cost_ranges, cost_ranges_endcoding)

# %%
print(df.TOTAL_DAYS_RANGES.value_counts())
# Out:
# 0 - 60       1703
# 60 - 90       797
# 90 - 120      528
# > 180         469
# 120 - 150     397
# 150 - 180     258
# Name: TOTAL_DAYS_RANGES, dtype: int64

# %%
print(df.EST_COST_RANGE.value_counts())
# Out:
# 0 - 10L       3579
# 25L - 50L      198
# 10L - 25L      185
# 50L - 1CR       86
# 1CR - 5CR       79
# > 10CR          13
# 5CR - 10CR      12
# Name: EST_COST_RANGE, dtype: int64

# %%
df['EST_COST_RANGE'].tail(15)
# Out:
# 4137    25L - 50L
# 4138      0 - 10L
# 4139      0 - 10L
# 4140      0 - 10L
# 4141      0 - 10L
# 4142      0 - 10L
# 4143      0 - 10L
# 4144      0 - 10L
# 4145      0 - 10L
# 4146    10L - 25L
# 4147      0 - 10L
# 4148      0 - 10L
# 4149      0 - 10L
# 4150      0 - 10L
# 4151      0 - 10L
# Name: EST_COST_RANGE, dtype: object

# %%
df = df.replace({'IS_PAC': {'N': False, 'Y': True}})

# %%
df = df.replace({'CONCURRENCE_BY': {np.nan: None}})

# %%
# required_cols = ["ESTIMATED_COST", "EST_COST_RANGE", "MODEOFTENDER", "METHOD_OF_PURCHASE", "FINANCIAL_POWER_CODE", "CFA_CODE", "CONCURRENCE_BY", "BUDGET_HEAD_CODE", "IS_PAC", "TOTAL_DAYS_RANGES"]
required_cols = ["EST_COST_RANGE", "MODEOFTENDER", "METHOD_OF_PURCHASE", "FINANCIAL_POWER_CODE", "CFA_CODE", "CONCURRENCE_BY", "BUDGET_HEAD_CODE", "IS_PAC", "TOTAL_DAYS_RANGES"]

# %%
new_df = df[required_cols]

# %%
new_df
# Out:
#      EST_COST_RANGE             MODEOFTENDER       METHOD_OF_PURCHASE  \
# 0           0 - 10L              Through LPC              Through LPC
# 1           0 - 10L  Procurement Through GeM  Procurement Through GeM
# 2           0 - 10L  Procurement Through GeM  Procurement Through GeM
# 3           0 - 10L  Procurement Through GeM  Procurement Through GeM
# 4           0 - 10L  Procurement Through GeM  Procurement Through GeM
# ...             ...                      ...                      ...
# 4147        0 - 10L  Procurement Through GeM  Procurement Through GeM
# 4148        0 - 10L  Procurement Through GeM  Procurement Through GeM
# 4149        0 - 10L  Procurement Through GeM  Procurement Through GeM
# 4150        0 - 10L  Procurement Through GeM  Procurement Through GeM
# 4151        0 - 10L  Procurement Through GeM  Procurement Through GeM
#
#       FINANCIAL_POWER_CODE CFA_CODE CONCURRENCE_BY BUDGET_HEAD_CODE  IS_PAC  \
# ...

# %%
new_df = temp
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-eafcde38dd20> in <module>
# ----> 1 new_df = temp
#
# NameError: name 'temp' is not defined

# %%
# !pip install apyori
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Created wheel for apyori: filename=apyori-1.1.2-py3-none-any.whl size=5973 sha256=c60374205ac9e156dc9a020c4da300aba03e69971fb861d6a11190a46b03e345
#   Stored in directory: /root/.cache/pip/wheels/cb/f6/e1/57973c631d27efd1a2f375bd6a83b2a616c4021f24aab84080
# Successfully built apyori
# ...

# %%
from apyori import apriori

# %%
new_df1 = []
for index, row in new_df.iterrows():
  if row['TOTAL_DAYS_RANGES'] == '120 - 150' or row['TOTAL_DAYS_RANGES'] == '150 - 180' or row['TOTAL_DAYS_RANGES'] == '> 180':
    new_df1.append(row)
new_df1 = pd.DataFrame(new_df1)
new_df1
# Out:
#      EST_COST_RANGE             MODEOFTENDER       METHOD_OF_PURCHASE  \
# 35          0 - 10L                  Limited                  Limited
# 38        10L - 25L  Procurement Through GeM  Procurement Through GeM
# 42        10L - 25L  Procurement Through GeM  Procurement Through GeM
# 50          0 - 10L            Single Tender            Single Tender
# 53        25L - 50L                     Open                     Open
# ...             ...                      ...                      ...
# 1160      1CR - 5CR                  Limited                  Limited
# 1161      1CR - 5CR                  Limited                  Limited
# 1165         > 10CR                     Open                     Open
# 1166        0 - 10L  Procurement Through GeM  Procurement Through GeM
# 1170        0 - 10L  Procurement Through GeM  Procurement Through GeM
#
#       FINANCIAL_POWER_CODE CFA_CODE CONCURRENCE_BY BUDGET_HEAD_CODE  IS_PAC  \
# ...

# %%
new_df_1_temp = pd.get_dummies(new_df1)
new_df_1_temp
# Out:
#       FINANCIAL_POWER_CODE  IS_PAC  EST_COST_RANGE_0 - 10L  \
# 35                  202014   False                       1
# 38                  205003   False                       0
# 42                  202001   False                       0
# 50                  202016   False                       1
# 53                  202004   False                       0
# ...                    ...     ...                     ...
# 1160                202008   False                       0
# 1161                202008   False                       0
# 1165                202005   False                       0
# 1166                202001   False                       1
# 1170                202002   False                       1
#
#       EST_COST_RANGE_10L - 25L  EST_COST_RANGE_1CR - 5CR  \
# 35                           0                         0
# 38                           1                         0
# 42                           1                         0
# ...

# %%
# 0.1,0.6,2,2
records = []
for i in range(0, 114):
    records.append([str(new_df1.values[i,u]) for u in range(0, 9)])

rules = apriori(records, min_support=0.14, min_confidence=0.70, min_lift=3, min_length = 5)

for i in rules:
  print(i)

results = list(rules)

# for i in range(len(results)):
#   y = frozenset(results[i][0].items())
#   x = dict(y)
#   print(x)

results_list = []
for i in range(0, len(results)):
    results_list.append('RULE:\t' + str(results[i][0]) + '\nSUPPORT:\t' + str(results[i][1]))
print(len(results_list))
for r in results_list:
  print(r)

# records = []
# for i in range(0, 114):
#     records.append([str(new_df_1_temp.values[i,u]) for u in range(0, 34)])

# rules = apriori(records, min_support=0.014, min_confidence=0.07, min_lift=3, min_length = 2)

# results = list(rules)

# results_list = []
# for i in range(0, len(results)):
#     results_list.append('RULE:\t' + str(results[i][0]) + '\nSUPPORT:\t' + str(results[i][1]))
# print(len(results_list))
# for r in results_list:
#   print(r)
# Out:
# RelationRecord(items=frozenset({'Limited', '202008'}), support=0.20175438596491227, ordered_statistics=[OrderedStatistic(items_base=frozenset({'202008'}), items_add=frozenset({'Limited'}), confidence=0.9583333333333334, lift=3.1214285714285714)])
# RelationRecord(items=frozenset({'DIR', 'Limited', '202008'}), support=0.20175438596491227, ordered_statistics=[OrderedStatistic(items_base=frozenset({'202008'}), items_add=frozenset({'DIR', 'Limited'}), confidence=0.9583333333333334, lift=3.213235294117647), OrderedStatistic(items_base=frozenset({'DIR', '202008'}), items_add=frozenset({'Limited'}), confidence=0.9583333333333334, lift=3.1214285714285714)])
# ...

# %%
records = []
for i in range(0, 1174):
    records.append([str(new_df.values[i,u]) for u in range(0, 9)])

rules = apriori(records, min_support=0.14, min_confidence=0.70, min_lift=3, min_length = 5)

results = list(rules)

results_list = []
for i in range(0, len(results)):
    results_list.append('RULE:\t' + str(results[i][0]) + '\nSUPPORT:\t' + str(results[i][1]))
print(len(results_list))

# for item in results_list:

#     # first index of the inner list
#     # Contains base item and add item
#     pair = item[0] 
#     items = [x for x in pair]
#     print("Rule: " + items[0] + " -> " + items[1])

#     #second index of the inner list
#     print("Support: " + str(item[1]))

#     #third index of the list located at 0th
#     #of the third index of the inner list

#     print("Confidence: " + str(item[2][0][2]))
#     print("Lift: " + str(item[2][0][3]))
#     print("=====================================")
results_list
# Out:
# 0
# []

# %%
temp = df.loc[df['TOTAL_DAYS_RANGES'] == '150 - 180']
temp
# Out:
#      SUPPLY_ORDER_NO   SUPPLY_ORDER_DATE   TOTAL_COST MODE_OF_TENDER_CODE  \
# 38          22GM0028 2021-04-28 11:46:41   2971796.28                  GM
# 53          22FC0003 2021-05-03 16:14:01   3496500.00                  op
# 99          22AT0011 2021-05-21 16:09:33   8783250.00                  lm
# 114         22AM0003 2021-05-31 14:26:06    130980.00                  st
# 127         22GM0064 2021-06-02 00:00:00    217500.00                  GM
# 226         22AT0026 2021-06-29 10:22:12  66074052.00                  lm
# 231         22SO0067 2021-06-30 14:33:44    227850.00                  lp
# 235         22AT0028 2021-06-30 14:49:24   4656201.58                  op
# 254         22DC0004 2021-07-05 11:13:11   3687137.00                  lm
# 255         22AT0030 2021-07-05 12:03:18   3204106.11                  st
# 361         22GM0181 2021-07-29 00:00:00    280000.00                  GM
# 507         22FC0030 2021-09-16 16:26:09   1831200.00                  lm
# ...

# %%
new_df
# Out:
#      EST_COST_RANGE             MODEOFTENDER       METHOD_OF_PURCHASE  \
# 0           0 - 10L              Through LPC              Through LPC
# 1           0 - 10L  Procurement Through GeM  Procurement Through GeM
# 2           0 - 10L  Procurement Through GeM  Procurement Through GeM
# 3           0 - 10L  Procurement Through GeM  Procurement Through GeM
# 4           0 - 10L  Procurement Through GeM  Procurement Through GeM
# ...             ...                      ...                      ...
# 4147        0 - 10L  Procurement Through GeM  Procurement Through GeM
# 4148        0 - 10L  Procurement Through GeM  Procurement Through GeM
# 4149        0 - 10L  Procurement Through GeM  Procurement Through GeM
# 4150        0 - 10L  Procurement Through GeM  Procurement Through GeM
# 4151        0 - 10L  Procurement Through GeM  Procurement Through GeM
#
#       FINANCIAL_POWER_CODE CFA_CODE CONCURRENCE_BY BUDGET_HEAD_CODE  IS_PAC
# ...

# %%
convert_dict = {'FINANCIAL_POWER_CODE': object,
                }
new_df = new_df.astype(convert_dict)
print(new_df.dtypes)
# Out:
# EST_COST_RANGE          object
# MODEOFTENDER            object
# METHOD_OF_PURCHASE      object
# FINANCIAL_POWER_CODE    object
# CFA_CODE                object
# CONCURRENCE_BY          object
# BUDGET_HEAD_CODE        object
# IS_PAC                    bool
# TOTAL_DAYS_RANGES       object
# dtype: object

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
x=new_df
x=x.drop('TOTAL_DAYS_RANGES',axis=1)
x = pd.get_dummies(x)
x
# Out:
#       IS_PAC  EST_COST_RANGE_0 - 10L  EST_COST_RANGE_10L - 25L  \
# 0      False                       1                         0
# 1      False                       1                         0
# 2      False                       1                         0
# 3      False                       1                         0
# 4      False                       1                         0
# ...      ...                     ...                       ...
# 4147   False                       1                         0
# 4148   False                       1                         0
# 4149   False                       1                         0
# 4150   False                       1                         0
# 4151   False                       1                         0
#
#       EST_COST_RANGE_1CR - 5CR  EST_COST_RANGE_25L - 50L  \
# 0                            0                         0
# 1                            0                         0
# ...

# %%
y=new_df['TOTAL_DAYS_RANGES']
y
# Out:
# 0          0 - 60
# 1          0 - 60
# 2          0 - 60
# 3          0 - 60
# 4          0 - 60
#           ...
# 4147        > 180
# 4148    120 - 150
# 4149     90 - 120
# 4150    150 - 180
# 4151    150 - 180
# Name: TOTAL_DAYS_RANGES, Length: 4152, dtype: object

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()
y= label_encoder.fit_transform(y)

# %%
x.shape
# Out:
# (4152, 95)

# %%
y.shape
# Out:
# (4152,)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.30)

# %%
clf = RandomForestClassifier(n_estimators = 1000)

# %%
y_train
# Out:
# array([3, 3, 0, ..., 1, 0, 1])

# %%
clf.fit(x_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=1000)

# %%
y_pred = clf.predict(x_test)

# %%
y_pred
# Out:
# array([0, 0, 0, ..., 0, 4, 5])

# %%
from sklearn import metrics
print("ACCURACY OF THE MODEL: ", metrics.accuracy_score(y_test, y_pred))
# Out:
# ACCURACY OF THE MODEL:  0.4895666131621188

# %%
# !sudo pip install xgboost
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import xgboost
from xgboost import XGBClassifier

# %%
model = XGBClassifier()
model = XGBClassifier(n_estimators=1000)

# %%
model.fit(x_train, y_train)
# Out:
# XGBClassifier(n_estimators=1000, objective='multi:softprob')

# %%
y_pred = model.predict(x_test)

# %%
print("ACCURACY OF THE MODEL: ", metrics.accuracy_score(y_test, y_pred))
# Out:
# ACCURACY OF THE MODEL:  0.5032102728731942

# %%
x_train = np.asarray(x_train).astype(np.float32)
x_test = np.asarray(x_test).astype(np.float32)

# %%
import tensorflow as tf

# %%
import keras

# %%
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(95,)),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(64, activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(20, activation='relu'),
    keras.layers.Dense(10, activation='softmax')
])

# %%
model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  flatten_8 (Flatten)         (None, 95)                0
#
#  dense_20 (Dense)            (None, 128)               12288
#
#  dense_21 (Dense)            (None, 64)                8256
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_22 (Dense)            (None, 20)                1300
#
#  dense_23 (Dense)            (None, 10)                210
#
# ...
# Total params: 22,054
# Trainable params: 22,054
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
history=model.fit(x_train, y_train,validation_data=(x_test,y_test),epochs=50)
# Out:
# Epoch 1/50
# 91/91 [==============================] - 1s 5ms/step - loss: 1.8221 - accuracy: 0.3802 - val_loss: 1.4402 - val_accuracy: 0.5008
# Epoch 2/50
# 91/91 [==============================] - 0s 3ms/step - loss: 1.4931 - accuracy: 0.4608 - val_loss: 1.3571 - val_accuracy: 0.5032
# Epoch 3/50
# 91/91 [==============================] - 0s 4ms/step - loss: 1.4302 - accuracy: 0.4663 - val_loss: 1.3358 - val_accuracy: 0.4928
# Epoch 4/50
# 91/91 [==============================] - 0s 3ms/step - loss: 1.3927 - accuracy: 0.4656 - val_loss: 1.3221 - val_accuracy: 0.5064
# Epoch 5/50
# 91/91 [==============================] - 0s 4ms/step - loss: 1.3948 - accuracy: 0.4721 - val_loss: 1.3233 - val_accuracy: 0.5112
# Epoch 6/50
# 91/91 [==============================] - 0s 3ms/step - loss: 1.3758 - accuracy: 0.4725 - val_loss: 1.3063 - val_accuracy: 0.5040
# Epoch 7/50
# ...

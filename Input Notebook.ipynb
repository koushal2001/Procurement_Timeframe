# %%
import numpy as np
import pandas as pd

# %%
filepath = 'https://github.com/koushal2001/procurement_timeframe/blob/main/dataset.xlsx?raw=true'
# filepath = '/content/drive/MyDrive/studentproject_arde_DATA.xlsx'
df = pd.read_excel(filepath, sheet_name='Sheet1')
df
# Out:
#      SUPPLY_ORDER_NO    SUPPLY_ORDER_DATE  TOTAL_COST MODE_OF_TENDER_CODE  \
# 0           22SO0001  2021-04-05 16:20:08   119650.23                  lp
# 1           22GM0001  2021-04-06 00:00:00   209600.00                  GM
# 2           22GM0007  2021-04-06 00:00:00     2100.00                  GM
# 3           22GM0008  2021-04-06 00:00:00    26800.00                  GM
# 4           22GM0002  2021-04-06 00:00:00     7978.00                  GM
# ...              ...                  ...         ...                 ...
# 4147        22GM0150            29-MAR-22   804800.00                  GM
# 4148        22GM0151            30-MAR-22    82368.00                  GM
# 4149        22GM0152            30-MAR-22   494765.74                  GM
# 4150        22GM0153            31-MAR-22    21888.00                  GM
# 4151        22GM0154            31-MAR-22    30550.00                  GM
#
#                  MODEOFTENDER PROCUREMENT_MODE_CODE    PROCUREMENT_MODE_DESC  \
# 0                 Through LPC                    SO      Supply orders  (SO)
# 1     Procurement Through GeM                    GM  Procurement through GeM
# 2     Procurement Through GeM                    GM  Procurement through GeM
# 3     Procurement Through GeM                    GM  Procurement through GeM
# 4     Procurement Through GeM                    GM  Procurement through GeM
# ...                       ...                   ...                      ...
# 4147  Procurement Through GeM                    GM  Procurement through GeM
# 4148  Procurement Through GeM                    GM  Procurement through GeM
# 4149  Procurement Through GeM                    GM  Procurement through GeM
# 4150  Procurement Through GeM                    GM  Procurement through GeM
# 4151  Procurement Through GeM                    GM  Procurement through GeM
#
#      DEMAND_NO    RFP_NO  FINANCIAL_POWER_CODE  ... BUDGET_HEAD_DESCRIPTION_1  \
# 0     21CAN114  21SOL310                202001  ...           Project Capital
# 1     21SME033       NaN                202001  ...           Project Revenue
# 2     21INT118       NaN                205013  ...           Project Revenue
# 3     21PNS048       NaN                205008  ...           Project Revenue
# 4     21CAA077       NaN                202002  ...           General Revenue
# ...        ...       ...                   ...  ...                       ...
# 4147  22604069  22GMT116                202002  ...           General Revenue
# 4148  22805008       NaN                202002  ...           General Revenue
# 4149  22406003  22GMT114                202002  ...           General Revenue
# 4150  22GME018       NaN                202001  ...           Project Capital
# 4151  22GME017       NaN                202001  ...           Project Capital
#
#       PROCUREMENT_MODE_DESC_1 IS_PAC CONCURRENCE_BY   CONCURRENCE_DATE_1  \
# 0         Supply orders  (SO)      N            NaN                  NaN
# 1     Procurement through GeM      N            NaN                  NaN
# 2     Procurement through GeM      N            NaN                  NaN
# 3     Procurement through GeM      N            IFA  2021-01-13 00:00:00
# 4     Procurement through GeM      N            NaN                  NaN
# ...                       ...    ...            ...                  ...
# 4147  Procurement through GeM      N            NaN                  NaN
# 4148  Procurement through GeM      N            NaN                  NaN
# 4149  Procurement through GeM      N            NaN                  NaN
# 4150  Procurement through GeM      N            NaN                  NaN
# 4151  Procurement through GeM      N            NaN                  NaN
#
#      CONCURRENCE_AMOUNT                    CFA CFA_APPROVAL_REFERENCE  \
# 0                   NaN  Director of Labs/Estt               21CAN114
# 1                   NaN  Director of Labs/Estt               21SME033
# 2                   NaN  Director of Labs/Estt               21INT118
# 3               26800.0  Director of Labs/Estt               21PNS048
# 4                   NaN  Director of Labs/Estt               21CAA077
# ...                 ...                    ...                    ...
# 4147                NaN  Director of Labs/Estt               22604069
# 4148                NaN  Director of Labs/Estt               22805008
# 4149                NaN  Director of Labs/Estt               22406003
# 4150                NaN       Project Director               22GME018
# 4151                NaN       Project Director               22GME017
#
#         CFA_APPROVAL_DATE APPROVAL_AMOUNT
# 0     2021-03-17 11:50:03          119650
# 1     2021-04-06 10:32:02          212478
# 2     2021-03-30 11:34:47            2200
# 3     2021-04-06 15:25:48           26800
# 4     2021-04-06 11:35:47            7978
# ...                   ...             ...
# 4147            16-DEC-21          799998
# 4148            22-MAR-22          142480
# 4149            08-FEB-22          497252
# 4150            01-NOV-21           61999
# 4151            01-NOV-21           68500
#
# [4152 rows x 48 columns]

# %%
df.head()
# Out:
#   SUPPLY_ORDER_NO    SUPPLY_ORDER_DATE  TOTAL_COST MODE_OF_TENDER_CODE  \
# 0        22SO0001  2021-04-05 16:20:08   119650.23                  lp
# 1        22GM0001  2021-04-06 00:00:00   209600.00                  GM
# 2        22GM0007  2021-04-06 00:00:00     2100.00                  GM
# 3        22GM0008  2021-04-06 00:00:00    26800.00                  GM
# 4        22GM0002  2021-04-06 00:00:00     7978.00                  GM
#
#               MODEOFTENDER PROCUREMENT_MODE_CODE    PROCUREMENT_MODE_DESC  \
# 0              Through LPC                    SO      Supply orders  (SO)
# 1  Procurement Through GeM                    GM  Procurement through GeM
# 2  Procurement Through GeM                    GM  Procurement through GeM
# 3  Procurement Through GeM                    GM  Procurement through GeM
# 4  Procurement Through GeM                    GM  Procurement through GeM
#
#   DEMAND_NO    RFP_NO  FINANCIAL_POWER_CODE  ... BUDGET_HEAD_DESCRIPTION_1  \
# 0  21CAN114  21SOL310                202001  ...           Project Capital
# 1  21SME033       NaN                202001  ...           Project Revenue
# 2  21INT118       NaN                205013  ...           Project Revenue
# 3  21PNS048       NaN                205008  ...           Project Revenue
# 4  21CAA077       NaN                202002  ...           General Revenue
#
#    PROCUREMENT_MODE_DESC_1 IS_PAC CONCURRENCE_BY   CONCURRENCE_DATE_1  \
# 0      Supply orders  (SO)      N            NaN                  NaN
# 1  Procurement through GeM      N            NaN                  NaN
# 2  Procurement through GeM      N            NaN                  NaN
# 3  Procurement through GeM      N            IFA  2021-01-13 00:00:00
# 4  Procurement through GeM      N            NaN                  NaN
#
#   CONCURRENCE_AMOUNT                    CFA CFA_APPROVAL_REFERENCE  \
# 0                NaN  Director of Labs/Estt               21CAN114
# 1                NaN  Director of Labs/Estt               21SME033
# 2                NaN  Director of Labs/Estt               21INT118
# 3            26800.0  Director of Labs/Estt               21PNS048
# 4                NaN  Director of Labs/Estt               21CAA077
#
#      CFA_APPROVAL_DATE APPROVAL_AMOUNT
# 0  2021-03-17 11:50:03          119650
# 1  2021-04-06 10:32:02          212478
# 2  2021-03-30 11:34:47            2200
# 3  2021-04-06 15:25:48           26800
# 4  2021-04-06 11:35:47            7978
#
# [5 rows x 48 columns]

# %%
save_df=df.tail(1)

# %%
save_df
# Out:
#      SUPPLY_ORDER_NO SUPPLY_ORDER_DATE  TOTAL_COST MODE_OF_TENDER_CODE  \
# 4151        22GM0154         31-MAR-22     30550.0                  GM
#
#                  MODEOFTENDER PROCUREMENT_MODE_CODE    PROCUREMENT_MODE_DESC  \
# 4151  Procurement Through GeM                    GM  Procurement through GeM
#
#      DEMAND_NO RFP_NO  FINANCIAL_POWER_CODE  ... BUDGET_HEAD_DESCRIPTION_1  \
# 4151  22GME017    NaN                202001  ...           Project Capital
#
#       PROCUREMENT_MODE_DESC_1 IS_PAC CONCURRENCE_BY CONCURRENCE_DATE_1  \
# 4151  Procurement through GeM      N            NaN                NaN
#
#      CONCURRENCE_AMOUNT               CFA CFA_APPROVAL_REFERENCE  \
# 4151                NaN  Project Director               22GME017
#
#      CFA_APPROVAL_DATE APPROVAL_AMOUNT
# 4151         01-NOV-21           68500
#
# [1 rows x 48 columns]

# %%
save_df

cols = {"TOTAL_COST": 116940,
"MODE_OF_TENDER_CODE": "GM",
"FINANCIAL_POWER_CODE": 202002,
"FINANCIAL_POWER_SERIAL_NO": 2.2,
"CFA_CODE": "DIR",
"GEM_CONTRACT_NO": "GEMC-511687735298818",
"BUDGET_HEAD_CODE": "GN",
"BUDGET_HEAD_DESCRIPTION": "General Revenue",
"MINOR_HEAD": 110,
"UNITCODE": 360000092,
"ESTIMATED_COST": 118200,
"DIVISION_NO": "024",
"FIN_POWER": 2.2,
"FIN_POWER_DEMAND_FS": 2.2,
"BUDGET_HEAD_DESCRIPTION_1": "General revenue",
"APPROVAL_AMOUNT": 118200,
"SUPPLY_ORDER_DATE": "2021-05-31"}

for col in cols:
  save_df[col]=cols[col]
# Out:
# <ipython-input-201-accb75ea317f>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   save_df[col]=cols[col]

# %%
save_df
# Out:
#      SUPPLY_ORDER_NO SUPPLY_ORDER_DATE  TOTAL_COST MODE_OF_TENDER_CODE  \
# 4151        22GM0154        2021-05-31      116940                  GM
#
#                  MODEOFTENDER PROCUREMENT_MODE_CODE    PROCUREMENT_MODE_DESC  \
# 4151  Procurement Through GeM                    GM  Procurement through GeM
#
#      DEMAND_NO RFP_NO  FINANCIAL_POWER_CODE  ...  BUDGET_HEAD_DESCRIPTION_1  \
# 4151  22GME017    NaN                202002  ...            General revenue
#
#       PROCUREMENT_MODE_DESC_1 IS_PAC CONCURRENCE_BY CONCURRENCE_DATE_1  \
# 4151  Procurement through GeM      N            NaN                NaN
#
#      CONCURRENCE_AMOUNT               CFA CFA_APPROVAL_REFERENCE  \
# 4151                NaN  Project Director               22GME017
#
#      CFA_APPROVAL_DATE APPROVAL_AMOUNT
# 4151         01-NOV-21          118200
#
# [1 rows x 48 columns]

# %%
# TOTAL_COST = input("Enter the total cost: ")
# MODE_OF_TENDER_CODE = input("Enter the mode of tender code: ")
# FINANCIAL_POWER_CODE = input("Enter the financial power code: ")
# FINANCIAL_POWER_SERIAL_NO = input("Enter the financial power serial number: ")
# CFA_CODE = input("Enter the CFA code: ")
# UO_NO = input("Enter the UO number: ")
# GEM_CONTRACT_NO = input("Enter the GEM contract number: ")
# BUDGET_HEAD_CODE = input("Enter the budget head code: ")
# BUDGET_HEAD_DESCRIPTION = input("Enter the budget head description: ")
# AGAINST_SANCTION_NO = input("Enter the against sanction number: ")
# MINOR_HEAD = input("Enter the minor head: ")
# UNITCODE = input("Enter the unit code: ")
# ESTIMATED_COST = input("Enter the estimated cost: ")
# DIVISION_NO = input("Enter the division number: ")
# FIN_POWER = input("Enter the financial power: ")
# FIN_POWER_DEMAND_FS = input("Enter the financial power demand FS: ")
# BUDGET_HEAD_DESCRIPTION_1 = input("Enter the budget head description 1: ")
# CONCURRENCE_BY = input("Enter the concurrence by: ")
# APPROVAL_AMOUNT = input("Enter the approval amount: ")
# SUPPLY_ORDER_DATE = input("Enter the supply order date (in the format 'YYYY-MM-DD'): ")
# from datetime import datetime
# SUPPLY_ORDER_DATE = datetime.strptime(SUPPLY_ORDER_DATE, '%Y-%m-%d')
TOTAL_COST = 116940
MODE_OF_TENDER_CODE = "GM"
FINANCIAL_POWER_CODE = 202002
FINANCIAL_POWER_SERIAL_NO = 2.2
CFA_CODE = "DIR"
# UO_NO = ""
GEM_CONTRACT_NO = "GEMC-511687735298818"
BUDGET_HEAD_CODE = "GN"
BUDGET_HEAD_DESCRIPTION = "General Revenue"
# AGAINST_SANCTION_NO = ""
MINOR_HEAD = 110
UNITCODE = 360000092
ESTIMATED_COST = 118200
DIVISION_NO = "024"
FIN_POWER = 2.2
FIN_POWER_DEMAND_FS = 2.2
BUDGET_HEAD_DESCRIPTION_1 = "General revenue"
# CONCURRENCE_BY = ""
APPROVAL_AMOUNT = 118200
SUPPLY_ORDER_DATE = "2021-05-31"
from datetime import datetime
SUPPLY_ORDER_DATE = datetime.strptime(SUPPLY_ORDER_DATE, '%Y-%m-%d')
'''
Enter the total cost: 116940
Enter the mode of tender code: GM
Enter the financial power code: 202002
Enter the financial power serial number: 2.2
Enter the CFA code: DIR
Enter the UO number: 
Enter the GEM contract number: GEMC-511687735298818
Enter the budget head code: GN
Enter the budget head description: General Revenue
Enter the against sanction number: 
Enter the minor head: 110
Enter the unit code: 360000092
Enter the estimated cost: 118200
Enter the division number: 024
Enter the financial power: 2.2
Enter the financial power demand FS: 2.2
Enter the budget head description 1: General revenue
Enter the concurrence by: 
Enter the approval amount: 118200
Enter the supply order date (in the format 'YYYY-MM-DD'): 2021-05-31'''
# Out:
# "\nEnter the total cost: 116940\nEnter the mode of tender code: GM\nEnter the financial power code: 202002\nEnter the financial power serial number: 2.2\nEnter the CFA code: DIR\nEnter the UO number: \nEnter the GEM contract number: GEMC-511687735298818\nEnter the budget head code: GN\nEnter the budget head description: General Revenue\nEnter the against sanction number: \nEnter the minor head: 110\nEnter the unit code: 360000092\nEnter the estimated cost: 118200\nEnter the division number: 024\nEnter the financial power: 2.2\nEnter the financial power demand FS: 2.2\nEnter the budget head description 1: General revenue\nEnter the concurrence by: \nEnter the approval amount: 118200\nEnter the supply order date (in the format 'YYYY-MM-DD'): 2021-05-31"

# %%
data = {'TOTAL_COST': [TOTAL_COST], 
        'MODE_OF_TENDER_CODE': [MODE_OF_TENDER_CODE], 
        'FINANCIAL_POWER_CODE': [FINANCIAL_POWER_CODE], 
        'FINANCIAL_POWER_SERIAL_NO': [FINANCIAL_POWER_SERIAL_NO], 
        'CFA_CODE': [CFA_CODE], 
        'UO_NO': [UO_NO], 
        'GEM_CONTRACT_NO': [GEM_CONTRACT_NO], 
        'BUDGET_HEAD_CODE': [BUDGET_HEAD_CODE], 
        'BUDGET_HEAD_DESCRIPTION': [BUDGET_HEAD_DESCRIPTION], 
        'AGAINST_SANCTION_NO': [AGAINST_SANCTION_NO], 
        'MINOR_HEAD': [MINOR_HEAD], 
        'UNITCODE': [UNITCODE], 
        'ESTIMATED_COST': [ESTIMATED_COST], 
        'DIVISION_NO': [DIVISION_NO], 
        'FIN_POWER': [FIN_POWER], 
        'FIN_POWER_DEMAND_FS': [FIN_POWER_DEMAND_FS], 
        'BUDGET_HEAD_DESCRIPTION_1': [BUDGET_HEAD_DESCRIPTION_1], 
        'CONCURRENCE_BY': [CONCURRENCE_BY], 
        'APPROVAL_AMOUNT': [APPROVAL_AMOUNT], 
        'SUPPLY_ORDER_DATE': [SUPPLY_ORDER_DATE]}

new_df = pd.DataFrame.from_dict(data)

save_df = save_df.append(new_df, True)
# Out:
# <ipython-input-140-efa71bae85d3>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   save_df = save_df.append(new_df, True)

# %%
df=df.append(save_df,True)
# Out:
# <ipython-input-203-4d6a05419d90>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=df.append(save_df,True)

# %%
df
# Out:
#      SUPPLY_ORDER_NO    SUPPLY_ORDER_DATE  TOTAL_COST MODE_OF_TENDER_CODE  \
# 0           22SO0001  2021-04-05 16:20:08   119650.23                  lp
# 1           22GM0001  2021-04-06 00:00:00   209600.00                  GM
# 2           22GM0007  2021-04-06 00:00:00     2100.00                  GM
# 3           22GM0008  2021-04-06 00:00:00    26800.00                  GM
# 4           22GM0002  2021-04-06 00:00:00     7978.00                  GM
# ...              ...                  ...         ...                 ...
# 4148        22GM0151            30-MAR-22    82368.00                  GM
# 4149        22GM0152            30-MAR-22   494765.74                  GM
# 4150        22GM0153            31-MAR-22    21888.00                  GM
# 4151        22GM0154            31-MAR-22    30550.00                  GM
# 4152        22GM0154           2021-05-31   116940.00                  GM
#
#                  MODEOFTENDER PROCUREMENT_MODE_CODE    PROCUREMENT_MODE_DESC  \
# 0                 Through LPC                    SO      Supply orders  (SO)
# 1     Procurement Through GeM                    GM  Procurement through GeM
# 2     Procurement Through GeM                    GM  Procurement through GeM
# 3     Procurement Through GeM                    GM  Procurement through GeM
# 4     Procurement Through GeM                    GM  Procurement through GeM
# ...                       ...                   ...                      ...
# 4148  Procurement Through GeM                    GM  Procurement through GeM
# 4149  Procurement Through GeM                    GM  Procurement through GeM
# 4150  Procurement Through GeM                    GM  Procurement through GeM
# 4151  Procurement Through GeM                    GM  Procurement through GeM
# 4152  Procurement Through GeM                    GM  Procurement through GeM
#
#      DEMAND_NO    RFP_NO  FINANCIAL_POWER_CODE  ... BUDGET_HEAD_DESCRIPTION_1  \
# 0     21CAN114  21SOL310                202001  ...           Project Capital
# 1     21SME033       NaN                202001  ...           Project Revenue
# 2     21INT118       NaN                205013  ...           Project Revenue
# 3     21PNS048       NaN                205008  ...           Project Revenue
# 4     21CAA077       NaN                202002  ...           General Revenue
# ...        ...       ...                   ...  ...                       ...
# 4148  22805008       NaN                202002  ...           General Revenue
# 4149  22406003  22GMT114                202002  ...           General Revenue
# 4150  22GME018       NaN                202001  ...           Project Capital
# 4151  22GME017       NaN                202001  ...           Project Capital
# 4152  22GME017       NaN                202002  ...           General revenue
#
#       PROCUREMENT_MODE_DESC_1 IS_PAC CONCURRENCE_BY   CONCURRENCE_DATE_1  \
# 0         Supply orders  (SO)      N            NaN                  NaN
# 1     Procurement through GeM      N            NaN                  NaN
# 2     Procurement through GeM      N            NaN                  NaN
# 3     Procurement through GeM      N            IFA  2021-01-13 00:00:00
# 4     Procurement through GeM      N            NaN                  NaN
# ...                       ...    ...            ...                  ...
# 4148  Procurement through GeM      N            NaN                  NaN
# 4149  Procurement through GeM      N            NaN                  NaN
# 4150  Procurement through GeM      N            NaN                  NaN
# 4151  Procurement through GeM      N            NaN                  NaN
# 4152  Procurement through GeM      N            NaN                  NaN
#
#      CONCURRENCE_AMOUNT                    CFA CFA_APPROVAL_REFERENCE  \
# 0                   NaN  Director of Labs/Estt               21CAN114
# 1                   NaN  Director of Labs/Estt               21SME033
# 2                   NaN  Director of Labs/Estt               21INT118
# 3               26800.0  Director of Labs/Estt               21PNS048
# 4                   NaN  Director of Labs/Estt               21CAA077
# ...                 ...                    ...                    ...
# 4148                NaN  Director of Labs/Estt               22805008
# 4149                NaN  Director of Labs/Estt               22406003
# 4150                NaN       Project Director               22GME018
# 4151                NaN       Project Director               22GME017
# 4152                NaN       Project Director               22GME017
#
#         CFA_APPROVAL_DATE APPROVAL_AMOUNT
# 0     2021-03-17 11:50:03          119650
# 1     2021-04-06 10:32:02          212478
# 2     2021-03-30 11:34:47            2200
# 3     2021-04-06 15:25:48           26800
# 4     2021-04-06 11:35:47            7978
# ...                   ...             ...
# 4148            22-MAR-22          142480
# 4149            08-FEB-22          497252
# 4150            01-NOV-21           61999
# 4151            01-NOV-21           68500
# 4152            01-NOV-21          118200
#
# [4153 rows x 48 columns]

# %%
df['SUPPLY_ORDER_DATE']=pd.to_datetime(df['SUPPLY_ORDER_DATE'])
df["SUPPLY_ORDER_DATE_Year"] = df["SUPPLY_ORDER_DATE"].dt.year
df["SUPPLY_ORDER_DATE_Month"] = df["SUPPLY_ORDER_DATE"].dt.month
df["SUPPLY_ORDER_DATE_Day"] = df["SUPPLY_ORDER_DATE"].dt.day
df['SUPPLY_ORDER_DATE_Time']=df['SUPPLY_ORDER_DATE'].dt.time

# %%
df.head(2)
# Out:
#   SUPPLY_ORDER_NO   SUPPLY_ORDER_DATE  TOTAL_COST MODE_OF_TENDER_CODE  \
# 0        22SO0001 2021-04-05 16:20:08   119650.23                  lp
# 1        22GM0001 2021-04-06 00:00:00   209600.00                  GM
#
#               MODEOFTENDER PROCUREMENT_MODE_CODE    PROCUREMENT_MODE_DESC  \
# 0              Through LPC                    SO      Supply orders  (SO)
# 1  Procurement Through GeM                    GM  Procurement through GeM
#
#   DEMAND_NO    RFP_NO  FINANCIAL_POWER_CODE  ... CONCURRENCE_DATE_1  \
# 0  21CAN114  21SOL310                202001  ...                NaN
# 1  21SME033       NaN                202001  ...                NaN
#
#   CONCURRENCE_AMOUNT                    CFA CFA_APPROVAL_REFERENCE  \
# 0                NaN  Director of Labs/Estt               21CAN114
# 1                NaN  Director of Labs/Estt               21SME033
#
#      CFA_APPROVAL_DATE APPROVAL_AMOUNT SUPPLY_ORDER_DATE_Year  \
# 0  2021-03-17 11:50:03          119650                   2021
# 1  2021-04-06 10:32:02          212478                   2021
#
#   SUPPLY_ORDER_DATE_Month SUPPLY_ORDER_DATE_Day SUPPLY_ORDER_DATE_Time
# 0                       4                     5               16:20:08
# 1                       4                     6               00:00:00
#
# [2 rows x 52 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4153 entries, 0 to 4152
# Data columns (total 52 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   SUPPLY_ORDER_NO            4153 non-null   object
#  1   SUPPLY_ORDER_DATE          4153 non-null   datetime64[ns]
#  2   TOTAL_COST                 4153 non-null   float64
#  3   MODE_OF_TENDER_CODE        4153 non-null   object
#  4   MODEOFTENDER               4153 non-null   object
#  5   PROCUREMENT_MODE_CODE      4153 non-null   object
#  6   PROCUREMENT_MODE_DESC      4153 non-null   object
#  7   DEMAND_NO                  4153 non-null   object
#  8   RFP_NO                     2730 non-null   object
#  9   FINANCIAL_POWER_CODE       4153 non-null   int64
#  10  FINANCIAL_POWER_SERIAL_NO  4153 non-null   object
#  11  CFA_CODE                   4053 non-null   object
#  12  CFA_DESCRIPTION            4053 non-null   object
#  13  SANCTION_DATE              4053 non-null   object
#  14  CONCURRENCE_LEVEL_CODE     156 non-null    object
#  15  CONCURRED_BY               156 non-null    object
#  16  UO_NO                      156 non-null    object
#  17  CONCURRENCE_DATE           156 non-null    object
#  18  GEM_CONTRACT_NO            1874 non-null   object
#  19  GEM_CONTRACT_DATE          1874 non-null   object
#  20  BUDGET_HEAD_CODE           4153 non-null   object
#  21  BUDGET_HEAD_DESCRIPTION    4153 non-null   object
#  22  AGAINST_SANCTION_NO        2097 non-null   object
#  23  MAJOR_HEAD                 4153 non-null   object
#  24  SUB_MAJOR_HEAD             0 non-null      float64
#  25  MINOR_HEAD                 4153 non-null   object
#  26  HEAD_CODE                  4153 non-null   object
#  27  UNITCODE                   4153 non-null   object
#  28  UNITCODE_DESCRIPTION       4153 non-null   object
#  29  RECEIPT_DETAILS            0 non-null      float64
#  30  DEMAND_NO_1                4153 non-null   object
#  31  DEMAND_DATE                4153 non-null   object
#  32  ESTIMATED_COST             4153 non-null   int64
#  33  DIVISION_NO                4153 non-null   object
#  34  DIVISION_NAME              4153 non-null   object
#  35  FIN_POWER                  4149 non-null   object
#  36  FIN_POWER_DEMAND_FS        1269 non-null   object
#  37  METHOD_OF_PURCHASE         4153 non-null   object
#  38  BUDGET_HEAD_DESCRIPTION_1  4153 non-null   object
#  39  PROCUREMENT_MODE_DESC_1    4153 non-null   object
#  40  IS_PAC                     4153 non-null   object
#  41  CONCURRENCE_BY             276 non-null    object
#  42  CONCURRENCE_DATE_1         276 non-null    object
#  43  CONCURRENCE_AMOUNT         276 non-null    float64
#  44  CFA                        4153 non-null   object
#  45  CFA_APPROVAL_REFERENCE     4153 non-null   object
#  46  CFA_APPROVAL_DATE          4153 non-null   object
#  47  APPROVAL_AMOUNT            4153 non-null   int64
#  48  SUPPLY_ORDER_DATE_Year     4153 non-null   int64
#  49  SUPPLY_ORDER_DATE_Month    4153 non-null   int64
#  50  SUPPLY_ORDER_DATE_Day      4153 non-null   int64
#  51  SUPPLY_ORDER_DATE_Time     4153 non-null   object
# dtypes: datetime64[ns](1), float64(4), int64(6), object(41)
# memory usage: 1.6+ MB

# %%
df['SANCTION_DATE']=pd.to_datetime(df['SANCTION_DATE'])
df["SANCTION_DATE_Year"] = df["SANCTION_DATE"].dt.year
df["SANCTION_DATE_Month"] = df["SANCTION_DATE"].dt.month
df["SANCTION_DATE_Day"] = df["SANCTION_DATE"].dt.day
df['SANCTION_DATE_Time']=df['SANCTION_DATE'].dt.time

df['CONCURRENCE_DATE']=pd.to_datetime(df['CONCURRENCE_DATE'])
df["CONCURRENCE_DATE_Year"] = df["CONCURRENCE_DATE"].dt.year
df["CONCURRENCE_DATE_Month"] = df["CONCURRENCE_DATE"].dt.month
df["CONCURRENCE_DATE_Day"] = df["CONCURRENCE_DATE"].dt.day
df['CONCURRENCE_DATE_Time']=df['CONCURRENCE_DATE'].dt.time

df['DEMAND_DATE']=pd.to_datetime(df['DEMAND_DATE'])
df["DEMAND_DATE_Year"] = df["DEMAND_DATE"].dt.year
df["DEMAND_DATE_Month"] = df["DEMAND_DATE"].dt.month
df["DEMAND_DATE_Day"] = df["DEMAND_DATE"].dt.day
df['DEMAND_DATE_Time']=df['DEMAND_DATE'].dt.time

df['CONCURRENCE_DATE']=pd.to_datetime(df['CONCURRENCE_DATE'])
df["CONCURRENCE_DATE_Year"] = df["CONCURRENCE_DATE"].dt.year
df["CONCURRENCE_DATE_Month"] = df["CONCURRENCE_DATE"].dt.month
df["CONCURRENCE_DATE_Day"] = df["CONCURRENCE_DATE"].dt.day
df['CONCURRENCE_DATE_Time']=df['CONCURRENCE_DATE'].dt.time

df['CFA_APPROVAL_DATE']=pd.to_datetime(df['CFA_APPROVAL_DATE'])
df["CFA_APPROVAL_DATE_Year"] = df["CFA_APPROVAL_DATE"].dt.year
df["CFA_APPROVAL_DATE_Month"] = df["CFA_APPROVAL_DATE"].dt.month
df["CFA_APPROVAL_DATE_Day"] = df["CFA_APPROVAL_DATE"].dt.day
df['CFA_APPROVAL_DATE_Time']=df['CFA_APPROVAL_DATE'].dt.time

# %%
df.shape
# Out:
# (4153, 68)

# %%
cols = df.columns.tolist()
cols
# Out:
# ['SUPPLY_ORDER_NO',
#  'SUPPLY_ORDER_DATE',
#  'TOTAL_COST',
#  'MODE_OF_TENDER_CODE',
#  'MODEOFTENDER',
#  'PROCUREMENT_MODE_CODE',
#  'PROCUREMENT_MODE_DESC',
#  'DEMAND_NO',
#  'RFP_NO',
#  'FINANCIAL_POWER_CODE',
#  'FINANCIAL_POWER_SERIAL_NO',
#  'CFA_CODE',
#  'CFA_DESCRIPTION',
#  'SANCTION_DATE',
#  'CONCURRENCE_LEVEL_CODE',
#  'CONCURRED_BY',
#  'UO_NO',
#  'CONCURRENCE_DATE',
#  'GEM_CONTRACT_NO',
#  'GEM_CONTRACT_DATE',
#  'BUDGET_HEAD_CODE',
#  'BUDGET_HEAD_DESCRIPTION',
#  'AGAINST_SANCTION_NO',
#  'MAJOR_HEAD',
#  'SUB_MAJOR_HEAD',
#  'MINOR_HEAD',
#  'HEAD_CODE',
#  'UNITCODE',
#  'UNITCODE_DESCRIPTION',
#  'RECEIPT_DETAILS',
#  'DEMAND_NO_1',
#  'DEMAND_DATE',
#  'ESTIMATED_COST',
#  'DIVISION_NO',
#  'DIVISION_NAME',
#  'FIN_POWER',
#  'FIN_POWER_DEMAND_FS',
#  'METHOD_OF_PURCHASE',
#  'BUDGET_HEAD_DESCRIPTION_1',
#  'PROCUREMENT_MODE_DESC_1',
#  'IS_PAC',
#  'CONCURRENCE_BY',
#  'CONCURRENCE_DATE_1',
#  'CONCURRENCE_AMOUNT',
#  'CFA',
#  'CFA_APPROVAL_REFERENCE',
#  'CFA_APPROVAL_DATE',
#  'APPROVAL_AMOUNT',
#  'SUPPLY_ORDER_DATE_Year',
#  'SUPPLY_ORDER_DATE_Month',
#  'SUPPLY_ORDER_DATE_Day',
#  'SUPPLY_ORDER_DATE_Time',
#  'SANCTION_DATE_Year',
#  'SANCTION_DATE_Month',
#  'SANCTION_DATE_Day',
#  'SANCTION_DATE_Time',
#  'CONCURRENCE_DATE_Year',
#  'CONCURRENCE_DATE_Month',
#  'CONCURRENCE_DATE_Day',
#  'CONCURRENCE_DATE_Time',
#  'DEMAND_DATE_Year',
#  'DEMAND_DATE_Month',
#  'DEMAND_DATE_Day',
#  'DEMAND_DATE_Time',
#  'CFA_APPROVAL_DATE_Year',
#  'CFA_APPROVAL_DATE_Month',
#  'CFA_APPROVAL_DATE_Day',
#  'CFA_APPROVAL_DATE_Time']

# %%
date_cols = ['SUPPLY_ORDER_DATE','DEMAND_DATE']
for col in date_cols:
  df[col] = pd.to_datetime(df[col])

# %%
df['TOTAL_DAYS'] = (df['SUPPLY_ORDER_DATE'] - df['DEMAND_DATE']).dt.days
df['TOTAL_DAYS']
# Out:
# 0        33
# 1        39
# 2        19
# 3        17
# 4        13
#        ...
# 4148    139
# 4149     98
# 4150    157
# 4151    160
# 4152   -144
# Name: TOTAL_DAYS, Length: 4153, dtype: int64

# %%
df.shape
# Out:
# (4153, 69)

# %%
df
# Out:
#      SUPPLY_ORDER_NO   SUPPLY_ORDER_DATE  TOTAL_COST MODE_OF_TENDER_CODE  \
# 0           22SO0001 2021-04-05 16:20:08   119650.23                  lp
# 1           22GM0001 2021-04-06 00:00:00   209600.00                  GM
# 2           22GM0007 2021-04-06 00:00:00     2100.00                  GM
# 3           22GM0008 2021-04-06 00:00:00    26800.00                  GM
# 4           22GM0002 2021-04-06 00:00:00     7978.00                  GM
# ...              ...                 ...         ...                 ...
# 4148        22GM0151 2022-03-30 00:00:00    82368.00                  GM
# 4149        22GM0152 2022-03-30 00:00:00   494765.74                  GM
# 4150        22GM0153 2022-03-31 00:00:00    21888.00                  GM
# 4151        22GM0154 2022-03-31 00:00:00    30550.00                  GM
# 4152        22GM0154 2021-05-31 00:00:00   116940.00                  GM
#
#                  MODEOFTENDER PROCUREMENT_MODE_CODE    PROCUREMENT_MODE_DESC  \
# 0                 Through LPC                    SO      Supply orders  (SO)
# 1     Procurement Through GeM                    GM  Procurement through GeM
# 2     Procurement Through GeM                    GM  Procurement through GeM
# 3     Procurement Through GeM                    GM  Procurement through GeM
# 4     Procurement Through GeM                    GM  Procurement through GeM
# ...                       ...                   ...                      ...
# 4148  Procurement Through GeM                    GM  Procurement through GeM
# 4149  Procurement Through GeM                    GM  Procurement through GeM
# 4150  Procurement Through GeM                    GM  Procurement through GeM
# 4151  Procurement Through GeM                    GM  Procurement through GeM
# 4152  Procurement Through GeM                    GM  Procurement through GeM
#
#      DEMAND_NO    RFP_NO  FINANCIAL_POWER_CODE  ... CONCURRENCE_DATE_Time  \
# 0     21CAN114  21SOL310                202001  ...                   NaT
# 1     21SME033       NaN                202001  ...                   NaT
# 2     21INT118       NaN                205013  ...                   NaT
# 3     21PNS048       NaN                205008  ...              00:00:00
# 4     21CAA077       NaN                202002  ...                   NaT
# ...        ...       ...                   ...  ...                   ...
# 4148  22805008       NaN                202002  ...                   NaN
# 4149  22406003  22GMT114                202002  ...                   NaN
# 4150  22GME018       NaN                202001  ...                   NaN
# 4151  22GME017       NaN                202001  ...                   NaN
# 4152  22GME017       NaN                202002  ...                   NaN
#
#      DEMAND_DATE_Year DEMAND_DATE_Month DEMAND_DATE_Day DEMAND_DATE_Time  \
# 0                2021                 3               3         09:48:52
# 1                2021                 2              25         17:41:42
# 2                2021                 3              17         10:38:57
# 3                2021                 3              19         15:50:52
# 4                2021                 3              23         11:03:35
# ...               ...               ...             ...              ...
# 4148             2021                11              11         00:00:00
# 4149             2021                12              22         00:00:00
# 4150             2021                10              25         00:00:00
# 4151             2021                10              22         00:00:00
# 4152             2021                10              22         00:00:00
#
#      CFA_APPROVAL_DATE_Year CFA_APPROVAL_DATE_Month CFA_APPROVAL_DATE_Day  \
# 0                      2021                       3                    17
# 1                      2021                       4                     6
# 2                      2021                       3                    30
# 3                      2021                       4                     6
# 4                      2021                       4                     6
# ...                     ...                     ...                   ...
# 4148                   2022                       3                    22
# 4149                   2022                       2                     8
# 4150                   2021                      11                     1
# 4151                   2021                      11                     1
# 4152                   2021                      11                     1
#
#      CFA_APPROVAL_DATE_Time TOTAL_DAYS
# 0                  11:50:03         33
# 1                  10:32:02         39
# 2                  11:34:47         19
# 3                  15:25:48         17
# 4                  11:35:47         13
# ...                     ...        ...
# 4148               00:00:00        139
# 4149               00:00:00         98
# 4150               00:00:00        157
# 4151               00:00:00        160
# 4152               00:00:00       -144
#
# [4153 rows x 69 columns]

# %%
df.isnull().sum()
# Out:
# SUPPLY_ORDER_NO            0
# SUPPLY_ORDER_DATE          0
# TOTAL_COST                 0
# MODE_OF_TENDER_CODE        0
# MODEOFTENDER               0
#                           ..
# CFA_APPROVAL_DATE_Year     0
# CFA_APPROVAL_DATE_Month    0
# CFA_APPROVAL_DATE_Day      0
# CFA_APPROVAL_DATE_Time     0
# TOTAL_DAYS                 0
# Length: 69, dtype: int64

# %%
date_cols = ['SUPPLY_ORDER_DATE', 'SANCTION_DATE', 'CONCURRENCE_DATE', 'GEM_CONTRACT_DATE', 'DEMAND_DATE', 'CONCURRENCE_DATE_1', 'CFA_APPROVAL_DATE']

# %%
import seaborn as sns
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

# %%
label_encoder = LabelEncoder()
df.iloc[:,0] = label_encoder.fit_transform(df.iloc[:,0]).astype('float64')
# Out:
# <ipython-input-218-8f095fd1c787>:2: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df.iloc[:,0] = label_encoder.fit_transform(df.iloc[:,0]).astype('float64')

# %%
df.dtypes
# Out:
# SUPPLY_ORDER_NO                   float64
# SUPPLY_ORDER_DATE          datetime64[ns]
# TOTAL_COST                        float64
# MODE_OF_TENDER_CODE                object
# MODEOFTENDER                       object
#                                 ...
# CFA_APPROVAL_DATE_Year              int64
# CFA_APPROVAL_DATE_Month             int64
# CFA_APPROVAL_DATE_Day               int64
# CFA_APPROVAL_DATE_Time             object
# TOTAL_DAYS                          int64
# Length: 69, dtype: object

# %%
df.columns.tolist()
# Out:
# ['SUPPLY_ORDER_NO',
#  'SUPPLY_ORDER_DATE',
#  'TOTAL_COST',
#  'MODE_OF_TENDER_CODE',
#  'MODEOFTENDER',
#  'PROCUREMENT_MODE_CODE',
#  'PROCUREMENT_MODE_DESC',
#  'DEMAND_NO',
#  'RFP_NO',
#  'FINANCIAL_POWER_CODE',
#  'FINANCIAL_POWER_SERIAL_NO',
#  'CFA_CODE',
#  'CFA_DESCRIPTION',
#  'SANCTION_DATE',
#  'CONCURRENCE_LEVEL_CODE',
#  'CONCURRED_BY',
#  'UO_NO',
#  'CONCURRENCE_DATE',
#  'GEM_CONTRACT_NO',
#  'GEM_CONTRACT_DATE',
#  'BUDGET_HEAD_CODE',
#  'BUDGET_HEAD_DESCRIPTION',
#  'AGAINST_SANCTION_NO',
#  'MAJOR_HEAD',
#  'SUB_MAJOR_HEAD',
#  'MINOR_HEAD',
#  'HEAD_CODE',
#  'UNITCODE',
#  'UNITCODE_DESCRIPTION',
#  'RECEIPT_DETAILS',
#  'DEMAND_NO_1',
#  'DEMAND_DATE',
#  'ESTIMATED_COST',
#  'DIVISION_NO',
#  'DIVISION_NAME',
#  'FIN_POWER',
#  'FIN_POWER_DEMAND_FS',
#  'METHOD_OF_PURCHASE',
#  'BUDGET_HEAD_DESCRIPTION_1',
#  'PROCUREMENT_MODE_DESC_1',
#  'IS_PAC',
#  'CONCURRENCE_BY',
#  'CONCURRENCE_DATE_1',
#  'CONCURRENCE_AMOUNT',
#  'CFA',
#  'CFA_APPROVAL_REFERENCE',
#  'CFA_APPROVAL_DATE',
#  'APPROVAL_AMOUNT',
#  'SUPPLY_ORDER_DATE_Year',
#  'SUPPLY_ORDER_DATE_Month',
#  'SUPPLY_ORDER_DATE_Day',
#  'SUPPLY_ORDER_DATE_Time',
#  'SANCTION_DATE_Year',
#  'SANCTION_DATE_Month',
#  'SANCTION_DATE_Day',
#  'SANCTION_DATE_Time',
#  'CONCURRENCE_DATE_Year',
#  'CONCURRENCE_DATE_Month',
#  'CONCURRENCE_DATE_Day',
#  'CONCURRENCE_DATE_Time',
#  'DEMAND_DATE_Year',
#  'DEMAND_DATE_Month',
#  'DEMAND_DATE_Day',
#  'DEMAND_DATE_Time',
#  'CFA_APPROVAL_DATE_Year',
#  'CFA_APPROVAL_DATE_Month',
#  'CFA_APPROVAL_DATE_Day',
#  'CFA_APPROVAL_DATE_Time',
#  'TOTAL_DAYS']

# %%
object_cols=['SUPPLY_ORDER_NO',
 'MODE_OF_TENDER_CODE',
 'MODEOFTENDER',
 'PROCUREMENT_MODE_CODE',
 'PROCUREMENT_MODE_DESC',
 'DEMAND_NO',
 'RFP_NO',
 'FINANCIAL_POWER_SERIAL_NO',
 'CFA_CODE',
 'CFA_DESCRIPTION',
 'CONCURRENCE_LEVEL_CODE',
 'CONCURRED_BY',
 'UO_NO',
 'GEM_CONTRACT_NO',
 'BUDGET_HEAD_CODE',
 'BUDGET_HEAD_DESCRIPTION',
 'AGAINST_SANCTION_NO',
 'MAJOR_HEAD',
 'MINOR_HEAD',
 'HEAD_CODE',
 'UNITCODE',
 'UNITCODE_DESCRIPTION',
 'DEMAND_NO_1',
 'DIVISION_NO',
 'DIVISION_NAME',
 'FIN_POWER',
 'FIN_POWER_DEMAND_FS',
 'METHOD_OF_PURCHASE',
 'BUDGET_HEAD_DESCRIPTION_1',
 'PROCUREMENT_MODE_DESC_1',
 'IS_PAC',
 'CONCURRENCE_BY',
 'CFA',

 'CFA_APPROVAL_REFERENCE']

label_encoder = LabelEncoder()
for i in object_cols:
  df[i]=df[i].astype(str)

  df[i] = label_encoder.fit_transform(df[i]).astype('float64')

# %%
df.dtypes
# Out:
# SUPPLY_ORDER_NO                   float64
# SUPPLY_ORDER_DATE          datetime64[ns]
# TOTAL_COST                        float64
# MODE_OF_TENDER_CODE               float64
# MODEOFTENDER                      float64
#                                 ...
# CFA_APPROVAL_DATE_Year              int64
# CFA_APPROVAL_DATE_Month             int64
# CFA_APPROVAL_DATE_Day               int64
# CFA_APPROVAL_DATE_Time             object
# TOTAL_DAYS                          int64
# Length: 69, dtype: object

# %%
df
# Out:
#       SUPPLY_ORDER_NO   SUPPLY_ORDER_DATE  TOTAL_COST  MODE_OF_TENDER_CODE  \
# 0              1285.0 2021-04-05 16:20:08   119650.23                  8.0
# 1               658.0 2021-04-06 00:00:00   209600.00                  2.0
# 2               664.0 2021-04-06 00:00:00     2100.00                  2.0
# 3               665.0 2021-04-06 00:00:00    26800.00                  2.0
# 4               659.0 2021-04-06 00:00:00     7978.00                  2.0
# ...               ...                 ...         ...                  ...
# 4148            824.0 2022-03-30 00:00:00    82368.00                  2.0
# 4149            825.0 2022-03-30 00:00:00   494765.74                  2.0
# 4150            826.0 2022-03-31 00:00:00    21888.00                  2.0
# 4151            827.0 2022-03-31 00:00:00    30550.00                  2.0
# 4152            827.0 2021-05-31 00:00:00   116940.00                  2.0
#
#       MODEOFTENDER  PROCUREMENT_MODE_CODE  PROCUREMENT_MODE_DESC  DEMAND_NO  \
# 0             13.0                   10.0                   17.0      123.0
# 1              6.0                    7.0                   11.0      454.0
# 2              6.0                    7.0                   11.0      394.0
# 3              6.0                    7.0                   11.0      433.0
# 4              6.0                    7.0                   11.0      116.0
# ...            ...                    ...                    ...        ...
# 4148           6.0                    7.0                   11.0     1453.0
# 4149           6.0                    7.0                   11.0     1276.0
# 4150           6.0                    7.0                   11.0     2995.0
# 4151           6.0                    7.0                   11.0     2994.0
# 4152           6.0                    7.0                   11.0     2994.0
#
#       RFP_NO  FINANCIAL_POWER_CODE  ...  CONCURRENCE_DATE_Time  \
# 0      135.0                202001  ...                    NaT
# 1     1372.0                202001  ...                    NaT
# 2     1372.0                205013  ...                    NaT
# 3     1372.0                205008  ...               00:00:00
# 4     1372.0                202002  ...                    NaT
# ...      ...                   ...  ...                    ...
# 4148  1372.0                202002  ...                    NaN
# 4149   555.0                202002  ...                    NaN
# 4150  1372.0                202001  ...                    NaN
# 4151  1372.0                202001  ...                    NaN
# 4152  1372.0                202002  ...                    NaN
#
#       DEMAND_DATE_Year  DEMAND_DATE_Month DEMAND_DATE_Day  DEMAND_DATE_Time  \
# 0                 2021                  3               3          09:48:52
# 1                 2021                  2              25          17:41:42
# 2                 2021                  3              17          10:38:57
# 3                 2021                  3              19          15:50:52
# 4                 2021                  3              23          11:03:35
# ...                ...                ...             ...               ...
# 4148              2021                 11              11          00:00:00
# 4149              2021                 12              22          00:00:00
# 4150              2021                 10              25          00:00:00
# 4151              2021                 10              22          00:00:00
# 4152              2021                 10              22          00:00:00
#
#       CFA_APPROVAL_DATE_Year  CFA_APPROVAL_DATE_Month CFA_APPROVAL_DATE_Day  \
# 0                       2021                        3                    17
# 1                       2021                        4                     6
# 2                       2021                        3                    30
# 3                       2021                        4                     6
# 4                       2021                        4                     6
# ...                      ...                      ...                   ...
# 4148                    2022                        3                    22
# 4149                    2022                        2                     8
# 4150                    2021                       11                     1
# 4151                    2021                       11                     1
# 4152                    2021                       11                     1
#
#       CFA_APPROVAL_DATE_Time TOTAL_DAYS
# 0                   11:50:03         33
# 1                   10:32:02         39
# 2                   11:34:47         19
# 3                   15:25:48         17
# 4                   11:35:47         13
# ...                      ...        ...
# 4148                00:00:00        139
# 4149                00:00:00         98
# 4150                00:00:00        157
# 4151                00:00:00        160
# 4152                00:00:00       -144
#
# [4153 rows x 69 columns]

# %%
print(df.isnull().sum())
# Out:
# SUPPLY_ORDER_NO            0
# SUPPLY_ORDER_DATE          0
# TOTAL_COST                 0
# MODE_OF_TENDER_CODE        0
# MODEOFTENDER               0
#                           ..
# CFA_APPROVAL_DATE_Year     0
# CFA_APPROVAL_DATE_Month    0
# CFA_APPROVAL_DATE_Day      0
# CFA_APPROVAL_DATE_Time     0
# TOTAL_DAYS                 0
# Length: 69, dtype: int64

# %%
df.drop(columns=["SANCTION_DATE_Year",            
"SANCTION_DATE_Month",           
"SANCTION_DATE_Day" ,            
"CONCURRENCE_DATE_Year" ,       
"CONCURRENCE_DATE_Month" ,      
"CONCURRENCE_DATE_Day" ],inplace=True)

# %%
null_cols=['SUB_MAJOR_HEAD','RECEIPT_DETAILS','CONCURRENCE_AMOUNT']
for i in null_cols:
  df.drop(i, axis='columns',inplace=True)

# %%
df.shape
# Out:
# (4153, 60)

# %%
df.isnull().sum()
# Out:
# SUPPLY_ORDER_NO                 0
# SUPPLY_ORDER_DATE               0
# TOTAL_COST                      0
# MODE_OF_TENDER_CODE             0
# MODEOFTENDER                    0
# PROCUREMENT_MODE_CODE           0
# PROCUREMENT_MODE_DESC           0
# DEMAND_NO                       0
# RFP_NO                          0
# FINANCIAL_POWER_CODE            0
# FINANCIAL_POWER_SERIAL_NO       0
# CFA_CODE                        0
# CFA_DESCRIPTION                 0
# SANCTION_DATE                 100
# CONCURRENCE_LEVEL_CODE          0
# CONCURRED_BY                    0
# UO_NO                           0
# CONCURRENCE_DATE             3997
# GEM_CONTRACT_NO                 0
# GEM_CONTRACT_DATE            2279
# BUDGET_HEAD_CODE                0
# BUDGET_HEAD_DESCRIPTION         0
# AGAINST_SANCTION_NO             0
# MAJOR_HEAD                      0
# MINOR_HEAD                      0
# HEAD_CODE                       0
# UNITCODE                        0
# UNITCODE_DESCRIPTION            0
# DEMAND_NO_1                     0
# DEMAND_DATE                     0
# ESTIMATED_COST                  0
# DIVISION_NO                     0
# DIVISION_NAME                   0
# FIN_POWER                       0
# FIN_POWER_DEMAND_FS             0
# METHOD_OF_PURCHASE              0
# BUDGET_HEAD_DESCRIPTION_1       0
# PROCUREMENT_MODE_DESC_1         0
# IS_PAC                          0
# CONCURRENCE_BY                  0
# CONCURRENCE_DATE_1           3877
# CFA                             0
# CFA_APPROVAL_REFERENCE          0
# CFA_APPROVAL_DATE               0
# APPROVAL_AMOUNT                 0
# SUPPLY_ORDER_DATE_Year          0
# SUPPLY_ORDER_DATE_Month         0
# SUPPLY_ORDER_DATE_Day           0
# SUPPLY_ORDER_DATE_Time          0
# SANCTION_DATE_Time            100
# CONCURRENCE_DATE_Time        3997
# DEMAND_DATE_Year                0
# DEMAND_DATE_Month               0
# DEMAND_DATE_Day                 0
# DEMAND_DATE_Time                0
# CFA_APPROVAL_DATE_Year          0
# CFA_APPROVAL_DATE_Month         0
# CFA_APPROVAL_DATE_Day           0
# CFA_APPROVAL_DATE_Time          0
# TOTAL_DAYS                      0
# dtype: int64

# %%
df.shape
# Out:
# (4153, 60)

# %%
corr = df.corr()
# Out:
# <ipython-input-230-45893e33df67>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = df.corr()

# %%
corr.shape
# Out:
# (48, 48)

# %%
corr.columns
# Out:
# Index(['SUPPLY_ORDER_NO', 'TOTAL_COST', 'MODE_OF_TENDER_CODE', 'MODEOFTENDER',
#        'PROCUREMENT_MODE_CODE', 'PROCUREMENT_MODE_DESC', 'DEMAND_NO', 'RFP_NO',
#        'FINANCIAL_POWER_CODE', 'FINANCIAL_POWER_SERIAL_NO', 'CFA_CODE',
#        'CFA_DESCRIPTION', 'CONCURRENCE_LEVEL_CODE', 'CONCURRED_BY', 'UO_NO',
#        'GEM_CONTRACT_NO', 'BUDGET_HEAD_CODE', 'BUDGET_HEAD_DESCRIPTION',
#        'AGAINST_SANCTION_NO', 'MAJOR_HEAD', 'MINOR_HEAD', 'HEAD_CODE',
#        'UNITCODE', 'UNITCODE_DESCRIPTION', 'DEMAND_NO_1', 'ESTIMATED_COST',
#        'DIVISION_NO', 'DIVISION_NAME', 'FIN_POWER', 'FIN_POWER_DEMAND_FS',
#        'METHOD_OF_PURCHASE', 'BUDGET_HEAD_DESCRIPTION_1',
#        'PROCUREMENT_MODE_DESC_1', 'IS_PAC', 'CONCURRENCE_BY', 'CFA',
#        'CFA_APPROVAL_REFERENCE', 'APPROVAL_AMOUNT', 'SUPPLY_ORDER_DATE_Year',
#        'SUPPLY_ORDER_DATE_Month', 'SUPPLY_ORDER_DATE_Day', 'DEMAND_DATE_Year',
#        'DEMAND_DATE_Month', 'DEMAND_DATE_Day', 'CFA_APPROVAL_DATE_Year',
#        'CFA_APPROVAL_DATE_Month', 'CFA_APPROVAL_DATE_Day', 'TOTAL_DAYS'],
#       dtype='object')

# %%
corr.columns[47]
# Out:
# 'TOTAL_DAYS'

# %%
df1=df[corr.columns]

# %%
df_last=df.tail(1)

# %%
df_last
# Out:
#       SUPPLY_ORDER_NO SUPPLY_ORDER_DATE  TOTAL_COST  MODE_OF_TENDER_CODE  \
# 4152            827.0        2021-05-31    116940.0                  2.0
#
#       MODEOFTENDER  PROCUREMENT_MODE_CODE  PROCUREMENT_MODE_DESC  DEMAND_NO  \
# 4152           6.0                    7.0                   11.0     2994.0
#
#       RFP_NO  FINANCIAL_POWER_CODE  ...  CONCURRENCE_DATE_Time  \
# 4152  1372.0                202002  ...                    NaT
#
#       DEMAND_DATE_Year  DEMAND_DATE_Month DEMAND_DATE_Day  DEMAND_DATE_Time  \
# 4152              2021                 10              22          00:00:00
#
#       CFA_APPROVAL_DATE_Year  CFA_APPROVAL_DATE_Month CFA_APPROVAL_DATE_Day  \
# 4152                    2021                       11                     1
#
#       CFA_APPROVAL_DATE_Time TOTAL_DAYS
# 4152                00:00:00       -144
#
# [1 rows x 60 columns]

# %%
sns.heatmap(corr)
# Out:
# <Axes: >

# %%
columns = np.full((corr.shape[0],), True, dtype=bool)
for i in range(corr.shape[0]):
  if corr.iloc[i,47] >= 0.8 or corr.iloc[i,47]<=-0.35 :
    if columns[i]:
      columns[i] = False

# %%
# selected_columns = df.columns[columns]
selected_columns = df1.columns[columns]

# %%
selected_columns
# Out:
# Index(['SUPPLY_ORDER_NO', 'TOTAL_COST', 'MODE_OF_TENDER_CODE', 'MODEOFTENDER',
#        'PROCUREMENT_MODE_DESC', 'FINANCIAL_POWER_CODE',
#        'FINANCIAL_POWER_SERIAL_NO', 'CFA_CODE', 'CFA_DESCRIPTION',
#        'CONCURRENCE_LEVEL_CODE', 'CONCURRED_BY', 'UO_NO', 'GEM_CONTRACT_NO',
#        'BUDGET_HEAD_CODE', 'BUDGET_HEAD_DESCRIPTION', 'AGAINST_SANCTION_NO',
#        'MAJOR_HEAD', 'MINOR_HEAD', 'HEAD_CODE', 'UNITCODE',
#        'UNITCODE_DESCRIPTION', 'ESTIMATED_COST', 'DIVISION_NO',
#        'DIVISION_NAME', 'FIN_POWER', 'FIN_POWER_DEMAND_FS',
#        'METHOD_OF_PURCHASE', 'BUDGET_HEAD_DESCRIPTION_1',
#        'PROCUREMENT_MODE_DESC_1', 'IS_PAC', 'CONCURRENCE_BY', 'CFA',
#        'APPROVAL_AMOUNT', 'SUPPLY_ORDER_DATE_Year', 'SUPPLY_ORDER_DATE_Month',
#        'SUPPLY_ORDER_DATE_Day', 'DEMAND_DATE_Month', 'DEMAND_DATE_Day',
#        'CFA_APPROVAL_DATE_Year', 'CFA_APPROVAL_DATE_Month',
#        'CFA_APPROVAL_DATE_Day'],
#       dtype='object')

# %%
data = df1[selected_columns]

# %%
data["TOTAL_DAYS"]=df1["TOTAL_DAYS"]
# Out:
# <ipython-input-242-01ed71df4b46>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["TOTAL_DAYS"]=df1["TOTAL_DAYS"]

# %%
data.shape
# Out:
# (4153, 42)

# %%
data
# Out:
#       SUPPLY_ORDER_NO  TOTAL_COST  MODE_OF_TENDER_CODE  MODEOFTENDER  \
# 0              1285.0   119650.23                  8.0          13.0
# 1               658.0   209600.00                  2.0           6.0
# 2               664.0     2100.00                  2.0           6.0
# 3               665.0    26800.00                  2.0           6.0
# 4               659.0     7978.00                  2.0           6.0
# ...               ...         ...                  ...           ...
# 4148            824.0    82368.00                  2.0           6.0
# 4149            825.0   494765.74                  2.0           6.0
# 4150            826.0    21888.00                  2.0           6.0
# 4151            827.0    30550.00                  2.0           6.0
# 4152            827.0   116940.00                  2.0           6.0
#
#       PROCUREMENT_MODE_DESC  FINANCIAL_POWER_CODE  FINANCIAL_POWER_SERIAL_NO  \
# 0                      17.0                202001                        0.0
# 1                      11.0                202001                        0.0
# 2                      11.0                205013                       15.0
# 3                      11.0                205008                       25.0
# 4                      11.0                202002                        4.0
# ...                     ...                   ...                        ...
# 4148                   11.0                202002                        4.0
# 4149                   11.0                202002                        4.0
# 4150                   11.0                202001                        0.0
# 4151                   11.0                202001                        0.0
# 4152                   11.0                202002                        4.0
#
#       CFA_CODE  CFA_DESCRIPTION  CONCURRENCE_LEVEL_CODE  ...  APPROVAL_AMOUNT  \
# 0          1.0              1.0                     4.0  ...           119650
# 1          1.0              1.0                     4.0  ...           212478
# 2          1.0              1.0                     4.0  ...             2200
# 3          1.0              1.0                     1.0  ...            26800
# 4          1.0              1.0                     4.0  ...             7978
# ...        ...              ...                     ...  ...              ...
# 4148       1.0              1.0                     4.0  ...           142480
# 4149       1.0              1.0                     4.0  ...           497252
# 4150       2.0              4.0                     4.0  ...            61999
# 4151       2.0              4.0                     4.0  ...            68500
# 4152       1.0              4.0                     4.0  ...           118200
#
#       SUPPLY_ORDER_DATE_Year  SUPPLY_ORDER_DATE_Month  SUPPLY_ORDER_DATE_Day  \
# 0                       2021                        4                      5
# 1                       2021                        4                      6
# 2                       2021                        4                      6
# 3                       2021                        4                      6
# 4                       2021                        4                      6
# ...                      ...                      ...                    ...
# 4148                    2022                        3                     30
# 4149                    2022                        3                     30
# 4150                    2022                        3                     31
# 4151                    2022                        3                     31
# 4152                    2021                        5                     31
#
#       DEMAND_DATE_Month  DEMAND_DATE_Day  CFA_APPROVAL_DATE_Year  \
# 0                     3                3                    2021
# 1                     2               25                    2021
# 2                     3               17                    2021
# 3                     3               19                    2021
# 4                     3               23                    2021
# ...                 ...              ...                     ...
# 4148                 11               11                    2022
# 4149                 12               22                    2022
# 4150                 10               25                    2021
# 4151                 10               22                    2021
# 4152                 10               22                    2021
#
#       CFA_APPROVAL_DATE_Month  CFA_APPROVAL_DATE_Day  TOTAL_DAYS
# 0                           3                     17          33
# 1                           4                      6          39
# 2                           3                     30          19
# 3                           4                      6          17
# 4                           4                      6          13
# ...                       ...                    ...         ...
# 4148                        3                     22         139
# 4149                        2                      8          98
# 4150                       11                      1         157
# 4151                       11                      1         160
# 4152                       11                      1        -144
#
# [4153 rows x 42 columns]

# %%
data.columns
# Out:
# Index(['SUPPLY_ORDER_NO', 'TOTAL_COST', 'MODE_OF_TENDER_CODE', 'MODEOFTENDER',
#        'PROCUREMENT_MODE_DESC', 'FINANCIAL_POWER_CODE',
#        'FINANCIAL_POWER_SERIAL_NO', 'CFA_CODE', 'CFA_DESCRIPTION',
#        'CONCURRENCE_LEVEL_CODE', 'CONCURRED_BY', 'UO_NO', 'GEM_CONTRACT_NO',
#        'BUDGET_HEAD_CODE', 'BUDGET_HEAD_DESCRIPTION', 'AGAINST_SANCTION_NO',
#        'MAJOR_HEAD', 'MINOR_HEAD', 'HEAD_CODE', 'UNITCODE',
#        'UNITCODE_DESCRIPTION', 'ESTIMATED_COST', 'DIVISION_NO',
#        'DIVISION_NAME', 'FIN_POWER', 'FIN_POWER_DEMAND_FS',
#        'METHOD_OF_PURCHASE', 'BUDGET_HEAD_DESCRIPTION_1',
#        'PROCUREMENT_MODE_DESC_1', 'IS_PAC', 'CONCURRENCE_BY', 'CFA',
#        'APPROVAL_AMOUNT', 'SUPPLY_ORDER_DATE_Year', 'SUPPLY_ORDER_DATE_Month',
#        'SUPPLY_ORDER_DATE_Day', 'DEMAND_DATE_Month', 'DEMAND_DATE_Day',
#        'CFA_APPROVAL_DATE_Year', 'CFA_APPROVAL_DATE_Month',
#        'CFA_APPROVAL_DATE_Day', 'TOTAL_DAYS'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4153 entries, 0 to 4152
# Data columns (total 42 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   SUPPLY_ORDER_NO            4153 non-null   float64
#  1   TOTAL_COST                 4153 non-null   float64
#  2   MODE_OF_TENDER_CODE        4153 non-null   float64
#  3   MODEOFTENDER               4153 non-null   float64
#  4   PROCUREMENT_MODE_DESC      4153 non-null   float64
#  5   FINANCIAL_POWER_CODE       4153 non-null   int64
#  6   FINANCIAL_POWER_SERIAL_NO  4153 non-null   float64
#  7   CFA_CODE                   4153 non-null   float64
#  8   CFA_DESCRIPTION            4153 non-null   float64
#  9   CONCURRENCE_LEVEL_CODE     4153 non-null   float64
#  10  CONCURRED_BY               4153 non-null   float64
#  11  UO_NO                      4153 non-null   float64
#  12  GEM_CONTRACT_NO            4153 non-null   float64
#  13  BUDGET_HEAD_CODE           4153 non-null   float64
#  14  BUDGET_HEAD_DESCRIPTION    4153 non-null   float64
#  15  AGAINST_SANCTION_NO        4153 non-null   float64
#  16  MAJOR_HEAD                 4153 non-null   float64
#  17  MINOR_HEAD                 4153 non-null   float64
#  18  HEAD_CODE                  4153 non-null   float64
#  19  UNITCODE                   4153 non-null   float64
#  20  UNITCODE_DESCRIPTION       4153 non-null   float64
#  21  ESTIMATED_COST             4153 non-null   int64
#  22  DIVISION_NO                4153 non-null   float64
#  23  DIVISION_NAME              4153 non-null   float64
#  24  FIN_POWER                  4153 non-null   float64
#  25  FIN_POWER_DEMAND_FS        4153 non-null   float64
#  26  METHOD_OF_PURCHASE         4153 non-null   float64
#  27  BUDGET_HEAD_DESCRIPTION_1  4153 non-null   float64
#  28  PROCUREMENT_MODE_DESC_1    4153 non-null   float64
#  29  IS_PAC                     4153 non-null   float64
#  30  CONCURRENCE_BY             4153 non-null   float64
#  31  CFA                        4153 non-null   float64
#  32  APPROVAL_AMOUNT            4153 non-null   int64
#  33  SUPPLY_ORDER_DATE_Year     4153 non-null   int64
#  34  SUPPLY_ORDER_DATE_Month    4153 non-null   int64
#  35  SUPPLY_ORDER_DATE_Day      4153 non-null   int64
#  36  DEMAND_DATE_Month          4153 non-null   int64
#  37  DEMAND_DATE_Day            4153 non-null   int64
#  38  CFA_APPROVAL_DATE_Year     4153 non-null   int64
#  39  CFA_APPROVAL_DATE_Month    4153 non-null   int64
#  40  CFA_APPROVAL_DATE_Day      4153 non-null   int64
#  41  TOTAL_DAYS                 4153 non-null   int64
# dtypes: float64(30), int64(12)
# memory usage: 1.3 MB

# %% [markdown]
# **Selecting columns based on p-value**

# %%
selected_columns=selected_columns[:len(selected_columns)]
selected_columns
# Out:
# Index(['SUPPLY_ORDER_NO', 'TOTAL_COST', 'MODE_OF_TENDER_CODE', 'MODEOFTENDER',
#        'PROCUREMENT_MODE_DESC', 'FINANCIAL_POWER_CODE',
#        'FINANCIAL_POWER_SERIAL_NO', 'CFA_CODE', 'CFA_DESCRIPTION',
#        'CONCURRENCE_LEVEL_CODE', 'CONCURRED_BY', 'UO_NO', 'GEM_CONTRACT_NO',
#        'BUDGET_HEAD_CODE', 'BUDGET_HEAD_DESCRIPTION', 'AGAINST_SANCTION_NO',
#        'MAJOR_HEAD', 'MINOR_HEAD', 'HEAD_CODE', 'UNITCODE',
#        'UNITCODE_DESCRIPTION', 'ESTIMATED_COST', 'DIVISION_NO',
#        'DIVISION_NAME', 'FIN_POWER', 'FIN_POWER_DEMAND_FS',
#        'METHOD_OF_PURCHASE', 'BUDGET_HEAD_DESCRIPTION_1',
#        'PROCUREMENT_MODE_DESC_1', 'IS_PAC', 'CONCURRENCE_BY', 'CFA',
#        'APPROVAL_AMOUNT', 'SUPPLY_ORDER_DATE_Year', 'SUPPLY_ORDER_DATE_Month',
#        'SUPPLY_ORDER_DATE_Day', 'DEMAND_DATE_Month', 'DEMAND_DATE_Day',
#        'CFA_APPROVAL_DATE_Year', 'CFA_APPROVAL_DATE_Month',
#        'CFA_APPROVAL_DATE_Day'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# SUPPLY_ORDER_NO              0
# TOTAL_COST                   0
# MODE_OF_TENDER_CODE          0
# MODEOFTENDER                 0
# PROCUREMENT_MODE_DESC        0
# FINANCIAL_POWER_CODE         0
# FINANCIAL_POWER_SERIAL_NO    0
# CFA_CODE                     0
# CFA_DESCRIPTION              0
# CONCURRENCE_LEVEL_CODE       0
# CONCURRED_BY                 0
# UO_NO                        0
# GEM_CONTRACT_NO              0
# BUDGET_HEAD_CODE             0
# BUDGET_HEAD_DESCRIPTION      0
# AGAINST_SANCTION_NO          0
# MAJOR_HEAD                   0
# MINOR_HEAD                   0
# HEAD_CODE                    0
# UNITCODE                     0
# UNITCODE_DESCRIPTION         0
# ESTIMATED_COST               0
# DIVISION_NO                  0
# DIVISION_NAME                0
# FIN_POWER                    0
# FIN_POWER_DEMAND_FS          0
# METHOD_OF_PURCHASE           0
# BUDGET_HEAD_DESCRIPTION_1    0
# PROCUREMENT_MODE_DESC_1      0
# IS_PAC                       0
# CONCURRENCE_BY               0
# CFA                          0
# APPROVAL_AMOUNT              0
# SUPPLY_ORDER_DATE_Year       0
# SUPPLY_ORDER_DATE_Month      0
# SUPPLY_ORDER_DATE_Day        0
# DEMAND_DATE_Month            0
# DEMAND_DATE_Day              0
# CFA_APPROVAL_DATE_Year       0
# CFA_APPROVAL_DATE_Month      0
# CFA_APPROVAL_DATE_Day        0
# TOTAL_DAYS                   0
# dtype: int64

# %%
data.shape
# Out:
# (4153, 42)

# %%
import statsmodels.api as sm
def backwardElimination(x, Y, sl, columns):
    numVars = len(x[0])
    for i in range(0, numVars):
        regressor_OLS = sm.OLS(Y, x).fit()
        maxVar = max(regressor_OLS.pvalues).astype(float)
        if maxVar > sl:
            for j in range(0, numVars - i):
                if (regressor_OLS.pvalues[j].astype(float) == maxVar):
                    x = np.delete(x, j, 1)
                    columns = np.delete(columns, j)
                    
    regressor_OLS.summary()
    return x, columns

# %%
SL = 0.05
data_modeled, selected_columns = backwardElimination(data.iloc[:,1:].values, data.iloc[:,0].values, SL, selected_columns)

# %%
result = pd.DataFrame()

# %%
len(data_modeled)
# Out:
# 4153

# %%
selected_columns
# Out:
# Index(['TOTAL_COST', 'MODE_OF_TENDER_CODE', 'FINANCIAL_POWER_CODE',
#        'FINANCIAL_POWER_SERIAL_NO', 'CFA_CODE', 'UO_NO', 'GEM_CONTRACT_NO',
#        'BUDGET_HEAD_CODE', 'BUDGET_HEAD_DESCRIPTION', 'AGAINST_SANCTION_NO',
#        'MINOR_HEAD', 'UNITCODE', 'ESTIMATED_COST', 'DIVISION_NO', 'FIN_POWER',
#        'FIN_POWER_DEMAND_FS', 'BUDGET_HEAD_DESCRIPTION_1', 'CONCURRENCE_BY',
#        'APPROVAL_AMOUNT', 'SUPPLY_ORDER_DATE_Year', 'SUPPLY_ORDER_DATE_Day'],
#       dtype='object')

# %%
result = pd.DataFrame(data = data_modeled, columns = selected_columns)

# %%
result
# Out:
#       TOTAL_COST  MODE_OF_TENDER_CODE  FINANCIAL_POWER_CODE  \
# 0            8.0                 13.0                   0.0
# 1            2.0                  6.0                   0.0
# 2            2.0                  6.0                  15.0
# 3            2.0                  6.0                  25.0
# 4            2.0                  6.0                   4.0
# ...          ...                  ...                   ...
# 4148         2.0                  6.0                   4.0
# 4149         2.0                  6.0                   4.0
# 4150         2.0                  6.0                   0.0
# 4151         2.0                  6.0                   0.0
# 4152         2.0                  6.0                   4.0
#
#       FINANCIAL_POWER_SERIAL_NO  CFA_CODE   UO_NO  GEM_CONTRACT_NO  \
# 0                           1.0       1.0  1866.0              5.0
# 1                           1.0       1.0   899.0              7.0
# 2                           1.0       1.0   268.0              7.0
# 3                           1.0       1.0  1836.0              7.0
# 4                           1.0       1.0  1765.0              2.0
# ...                         ...       ...     ...              ...
# 4148                        1.0       1.0  1291.0              2.0
# 4149                        1.0       1.0  1746.0              2.0
# 4150                        2.0       4.0  1602.0              5.0
# 4151                        2.0       4.0   969.0              5.0
# 4152                        1.0       4.0   747.0              2.0
#
#       BUDGET_HEAD_CODE  BUDGET_HEAD_DESCRIPTION  AGAINST_SANCTION_NO  ...  \
# 0                  8.0                     58.0                  3.0  ...
# 1                  9.0                    140.0                  2.0  ...
# 2                  9.0                     50.0                  2.0  ...
# 3                  9.0                     56.0                  2.0  ...
# 4                  3.0                    162.0                  2.0  ...
# ...                ...                      ...                  ...  ...
# 4148               3.0                    162.0                  2.0  ...
# 4149               3.0                    162.0                  2.0  ...
# 4150               8.0                    100.0                  3.0  ...
# 4151               8.0                    100.0                  3.0  ...
# 4152               3.0                    100.0                  3.0  ...
#
#       UNITCODE  ESTIMATED_COST  DIVISION_NO  FIN_POWER  FIN_POWER_DEMAND_FS  \
# 0         47.0           133.0        185.0       22.0                 13.0
# 1         57.0           273.0        227.0       22.0                  6.0
# 2         34.0           225.0        150.0       22.0                  6.0
# 3         63.0           246.0        196.0       22.0                  6.0
# 4         61.0           131.0          6.0       22.0                  6.0
# ...        ...             ...          ...        ...                  ...
# 4148      69.0           106.0        257.0        3.0                  6.0
# 4149      69.0            52.0        215.0       22.0                  6.0
# 4150      92.0           206.0        114.0        0.0                  6.0
# 4151      92.0           206.0        114.0        0.0                  6.0
# 4152      92.0             0.0        114.0        3.0                  6.0
#
#       BUDGET_HEAD_DESCRIPTION_1  CONCURRENCE_BY  APPROVAL_AMOUNT  \
# 0                          17.0             1.0           2021.0
# 1                          11.0             1.0           2021.0
# 2                          11.0             1.0           2021.0
# 3                          11.0             1.0           2021.0
# 4                          11.0             1.0           2021.0
# ...                         ...             ...              ...
# 4148                       11.0             1.0           2022.0
# 4149                       11.0             1.0           2022.0
# 4150                       11.0             4.0           2022.0
# 4151                       11.0             4.0           2022.0
# 4152                       11.0             4.0           2021.0
#
#       SUPPLY_ORDER_DATE_Year  SUPPLY_ORDER_DATE_Day
# 0                        4.0                    3.0
# 1                        4.0                    2.0
# 2                        4.0                    3.0
# 3                        4.0                    3.0
# 4                        4.0                    3.0
# ...                      ...                    ...
# 4148                     3.0                   11.0
# 4149                     3.0                   12.0
# 4150                     3.0                   10.0
# 4151                     3.0                   10.0
# 4152                     5.0                   10.0
#
# [4153 rows x 21 columns]

# %%
result['TOTAL_DAYS']=data['TOTAL_DAYS']

# %%
result
# Out:
#       TOTAL_COST  MODE_OF_TENDER_CODE  FINANCIAL_POWER_CODE  \
# 0            8.0                 13.0                   0.0
# 1            2.0                  6.0                   0.0
# 2            2.0                  6.0                  15.0
# 3            2.0                  6.0                  25.0
# 4            2.0                  6.0                   4.0
# ...          ...                  ...                   ...
# 4148         2.0                  6.0                   4.0
# 4149         2.0                  6.0                   4.0
# 4150         2.0                  6.0                   0.0
# 4151         2.0                  6.0                   0.0
# 4152         2.0                  6.0                   4.0
#
#       FINANCIAL_POWER_SERIAL_NO  CFA_CODE   UO_NO  GEM_CONTRACT_NO  \
# 0                           1.0       1.0  1866.0              5.0
# 1                           1.0       1.0   899.0              7.0
# 2                           1.0       1.0   268.0              7.0
# 3                           1.0       1.0  1836.0              7.0
# 4                           1.0       1.0  1765.0              2.0
# ...                         ...       ...     ...              ...
# 4148                        1.0       1.0  1291.0              2.0
# 4149                        1.0       1.0  1746.0              2.0
# 4150                        2.0       4.0  1602.0              5.0
# 4151                        2.0       4.0   969.0              5.0
# 4152                        1.0       4.0   747.0              2.0
#
#       BUDGET_HEAD_CODE  BUDGET_HEAD_DESCRIPTION  AGAINST_SANCTION_NO  ...  \
# 0                  8.0                     58.0                  3.0  ...
# 1                  9.0                    140.0                  2.0  ...
# 2                  9.0                     50.0                  2.0  ...
# 3                  9.0                     56.0                  2.0  ...
# 4                  3.0                    162.0                  2.0  ...
# ...                ...                      ...                  ...  ...
# 4148               3.0                    162.0                  2.0  ...
# 4149               3.0                    162.0                  2.0  ...
# 4150               8.0                    100.0                  3.0  ...
# 4151               8.0                    100.0                  3.0  ...
# 4152               3.0                    100.0                  3.0  ...
#
#       ESTIMATED_COST  DIVISION_NO  FIN_POWER  FIN_POWER_DEMAND_FS  \
# 0              133.0        185.0       22.0                 13.0
# 1              273.0        227.0       22.0                  6.0
# 2              225.0        150.0       22.0                  6.0
# 3              246.0        196.0       22.0                  6.0
# 4              131.0          6.0       22.0                  6.0
# ...              ...          ...        ...                  ...
# 4148           106.0        257.0        3.0                  6.0
# 4149            52.0        215.0       22.0                  6.0
# 4150           206.0        114.0        0.0                  6.0
# 4151           206.0        114.0        0.0                  6.0
# 4152             0.0        114.0        3.0                  6.0
#
#       BUDGET_HEAD_DESCRIPTION_1  CONCURRENCE_BY  APPROVAL_AMOUNT  \
# 0                          17.0             1.0           2021.0
# 1                          11.0             1.0           2021.0
# 2                          11.0             1.0           2021.0
# 3                          11.0             1.0           2021.0
# 4                          11.0             1.0           2021.0
# ...                         ...             ...              ...
# 4148                       11.0             1.0           2022.0
# 4149                       11.0             1.0           2022.0
# 4150                       11.0             4.0           2022.0
# 4151                       11.0             4.0           2022.0
# 4152                       11.0             4.0           2021.0
#
#       SUPPLY_ORDER_DATE_Year  SUPPLY_ORDER_DATE_Day  TOTAL_DAYS
# 0                        4.0                    3.0          33
# 1                        4.0                    2.0          39
# 2                        4.0                    3.0          19
# 3                        4.0                    3.0          17
# 4                        4.0                    3.0          13
# ...                      ...                    ...         ...
# 4148                     3.0                   11.0         139
# 4149                     3.0                   12.0          98
# 4150                     3.0                   10.0         157
# 4151                     3.0                   10.0         160
# 4152                     5.0                   10.0        -144
#
# [4153 rows x 22 columns]

# %%
data=result

# %%
def range_encoding(df, source_col_name, dest_col_name, ranges, encoding):
  ranges_result = []
  for val in df[source_col_name]:
    flag = False
    for i in range(len(encoding) - 1):
      if ranges[i][0] <= val <= ranges[i][1]:
        ranges_result.append(encoding[i])
        flag = True
        break
    if not flag:
      ranges_result.append(encoding[len(encoding) - 1])

  df[dest_col_name] = ranges_result
  return df

# %%
day_ranges = [(0, 60), (61, 90), (91, 120), (121, 150), (151, 180)]
day_ranges_encoding = ['0 - 60', '60 - 90', '90 - 120', '120 - 150', '150 - 180', '> 180']

data = range_encoding(data, 'TOTAL_DAYS', 'TOTAL_DAYS_RANGES', day_ranges, day_ranges_encoding)

# %%
data
# Out:
#       TOTAL_COST  MODE_OF_TENDER_CODE  FINANCIAL_POWER_CODE  \
# 0            8.0                 13.0                   0.0
# 1            2.0                  6.0                   0.0
# 2            2.0                  6.0                  15.0
# 3            2.0                  6.0                  25.0
# 4            2.0                  6.0                   4.0
# ...          ...                  ...                   ...
# 4148         2.0                  6.0                   4.0
# 4149         2.0                  6.0                   4.0
# 4150         2.0                  6.0                   0.0
# 4151         2.0                  6.0                   0.0
# 4152         2.0                  6.0                   4.0
#
#       FINANCIAL_POWER_SERIAL_NO  CFA_CODE   UO_NO  GEM_CONTRACT_NO  \
# 0                           1.0       1.0  1866.0              5.0
# 1                           1.0       1.0   899.0              7.0
# 2                           1.0       1.0   268.0              7.0
# 3                           1.0       1.0  1836.0              7.0
# 4                           1.0       1.0  1765.0              2.0
# ...                         ...       ...     ...              ...
# 4148                        1.0       1.0  1291.0              2.0
# 4149                        1.0       1.0  1746.0              2.0
# 4150                        2.0       4.0  1602.0              5.0
# 4151                        2.0       4.0   969.0              5.0
# 4152                        1.0       4.0   747.0              2.0
#
#       BUDGET_HEAD_CODE  BUDGET_HEAD_DESCRIPTION  AGAINST_SANCTION_NO  ...  \
# 0                  8.0                     58.0                  3.0  ...
# 1                  9.0                    140.0                  2.0  ...
# 2                  9.0                     50.0                  2.0  ...
# 3                  9.0                     56.0                  2.0  ...
# 4                  3.0                    162.0                  2.0  ...
# ...                ...                      ...                  ...  ...
# 4148               3.0                    162.0                  2.0  ...
# 4149               3.0                    162.0                  2.0  ...
# 4150               8.0                    100.0                  3.0  ...
# 4151               8.0                    100.0                  3.0  ...
# 4152               3.0                    100.0                  3.0  ...
#
#       DIVISION_NO  FIN_POWER  FIN_POWER_DEMAND_FS  BUDGET_HEAD_DESCRIPTION_1  \
# 0           185.0       22.0                 13.0                       17.0
# 1           227.0       22.0                  6.0                       11.0
# 2           150.0       22.0                  6.0                       11.0
# 3           196.0       22.0                  6.0                       11.0
# 4             6.0       22.0                  6.0                       11.0
# ...           ...        ...                  ...                        ...
# 4148        257.0        3.0                  6.0                       11.0
# 4149        215.0       22.0                  6.0                       11.0
# 4150        114.0        0.0                  6.0                       11.0
# 4151        114.0        0.0                  6.0                       11.0
# 4152        114.0        3.0                  6.0                       11.0
#
#       CONCURRENCE_BY  APPROVAL_AMOUNT  SUPPLY_ORDER_DATE_Year  \
# 0                1.0           2021.0                     4.0
# 1                1.0           2021.0                     4.0
# 2                1.0           2021.0                     4.0
# 3                1.0           2021.0                     4.0
# 4                1.0           2021.0                     4.0
# ...              ...              ...                     ...
# 4148             1.0           2022.0                     3.0
# 4149             1.0           2022.0                     3.0
# 4150             4.0           2022.0                     3.0
# 4151             4.0           2022.0                     3.0
# 4152             4.0           2021.0                     5.0
#
#       SUPPLY_ORDER_DATE_Day  TOTAL_DAYS  TOTAL_DAYS_RANGES
# 0                       3.0          33             0 - 60
# 1                       2.0          39             0 - 60
# 2                       3.0          19             0 - 60
# 3                       3.0          17             0 - 60
# 4                       3.0          13             0 - 60
# ...                     ...         ...                ...
# 4148                   11.0         139          120 - 150
# 4149                   12.0          98           90 - 120
# 4150                   10.0         157          150 - 180
# 4151                   10.0         160          150 - 180
# 4152                   10.0        -144              > 180
#
# [4153 rows x 23 columns]

# %%
data.drop('TOTAL_DAYS',axis='columns',inplace=True)

# %%
data
# Out:
#       TOTAL_COST  MODE_OF_TENDER_CODE  FINANCIAL_POWER_CODE  \
# 0            8.0                 13.0                   0.0
# 1            2.0                  6.0                   0.0
# 2            2.0                  6.0                  15.0
# 3            2.0                  6.0                  25.0
# 4            2.0                  6.0                   4.0
# ...          ...                  ...                   ...
# 4148         2.0                  6.0                   4.0
# 4149         2.0                  6.0                   4.0
# 4150         2.0                  6.0                   0.0
# 4151         2.0                  6.0                   0.0
# 4152         2.0                  6.0                   4.0
#
#       FINANCIAL_POWER_SERIAL_NO  CFA_CODE   UO_NO  GEM_CONTRACT_NO  \
# 0                           1.0       1.0  1866.0              5.0
# 1                           1.0       1.0   899.0              7.0
# 2                           1.0       1.0   268.0              7.0
# 3                           1.0       1.0  1836.0              7.0
# 4                           1.0       1.0  1765.0              2.0
# ...                         ...       ...     ...              ...
# 4148                        1.0       1.0  1291.0              2.0
# 4149                        1.0       1.0  1746.0              2.0
# 4150                        2.0       4.0  1602.0              5.0
# 4151                        2.0       4.0   969.0              5.0
# 4152                        1.0       4.0   747.0              2.0
#
#       BUDGET_HEAD_CODE  BUDGET_HEAD_DESCRIPTION  AGAINST_SANCTION_NO  ...  \
# 0                  8.0                     58.0                  3.0  ...
# 1                  9.0                    140.0                  2.0  ...
# 2                  9.0                     50.0                  2.0  ...
# 3                  9.0                     56.0                  2.0  ...
# 4                  3.0                    162.0                  2.0  ...
# ...                ...                      ...                  ...  ...
# 4148               3.0                    162.0                  2.0  ...
# 4149               3.0                    162.0                  2.0  ...
# 4150               8.0                    100.0                  3.0  ...
# 4151               8.0                    100.0                  3.0  ...
# 4152               3.0                    100.0                  3.0  ...
#
#       ESTIMATED_COST  DIVISION_NO  FIN_POWER  FIN_POWER_DEMAND_FS  \
# 0              133.0        185.0       22.0                 13.0
# 1              273.0        227.0       22.0                  6.0
# 2              225.0        150.0       22.0                  6.0
# 3              246.0        196.0       22.0                  6.0
# 4              131.0          6.0       22.0                  6.0
# ...              ...          ...        ...                  ...
# 4148           106.0        257.0        3.0                  6.0
# 4149            52.0        215.0       22.0                  6.0
# 4150           206.0        114.0        0.0                  6.0
# 4151           206.0        114.0        0.0                  6.0
# 4152             0.0        114.0        3.0                  6.0
#
#       BUDGET_HEAD_DESCRIPTION_1  CONCURRENCE_BY  APPROVAL_AMOUNT  \
# 0                          17.0             1.0           2021.0
# 1                          11.0             1.0           2021.0
# 2                          11.0             1.0           2021.0
# 3                          11.0             1.0           2021.0
# 4                          11.0             1.0           2021.0
# ...                         ...             ...              ...
# 4148                       11.0             1.0           2022.0
# 4149                       11.0             1.0           2022.0
# 4150                       11.0             4.0           2022.0
# 4151                       11.0             4.0           2022.0
# 4152                       11.0             4.0           2021.0
#
#       SUPPLY_ORDER_DATE_Year  SUPPLY_ORDER_DATE_Day  TOTAL_DAYS_RANGES
# 0                        4.0                    3.0             0 - 60
# 1                        4.0                    2.0             0 - 60
# 2                        4.0                    3.0             0 - 60
# 3                        4.0                    3.0             0 - 60
# 4                        4.0                    3.0             0 - 60
# ...                      ...                    ...                ...
# 4148                     3.0                   11.0          120 - 150
# 4149                     3.0                   12.0           90 - 120
# 4150                     3.0                   10.0          150 - 180
# 4151                     3.0                   10.0          150 - 180
# 4152                     5.0                   10.0              > 180
#
# [4153 rows x 22 columns]

# %%
to_predict=data.tail(1)

# %%
to_predict=to_predict.drop(columns=['TOTAL_DAYS_RANGES'])

# %%
data = data.drop(index=df.index[-1])

# %%
data.shape
# Out:
# (4152, 22)

# %%
data['TOTAL_DAYS_RANGES'].value_counts()
# Out:
# 0 - 60       1703
# 60 - 90       797
# 90 - 120      528
# > 180         469
# 120 - 150     397
# 150 - 180     258
# Name: TOTAL_DAYS_RANGES, dtype: int64

# %%
data['TOTAL_DAYS_RANGES']=label_encoder.fit_transform(data['TOTAL_DAYS_RANGES']).astype('int64')

# %%
data['TOTAL_DAYS_RANGES'].value_counts()
# Out:
# 0    1703
# 3     797
# 4     528
# 5     469
# 1     397
# 2     258
# Name: TOTAL_DAYS_RANGES, dtype: int64

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state = 4)
imbalanced_y=data["TOTAL_DAYS_RANGES"]
imbalanced_x=data
imbalanced_x=imbalanced_x.drop(["TOTAL_DAYS_RANGES"],axis=1)
balanced_x, balanced_y = sm.fit_resample(imbalanced_x, imbalanced_y.ravel())

# %%
np.unique(balanced_y,return_counts=True)
# Out:
# (array([0, 1, 2, 3, 4, 5]), array([1703, 1703, 1703, 1703, 1703, 1703]))

# %%
x=balanced_x
y=balanced_y

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.30,stratify=y)

# %%
x_train.columns
# Out:
# Index(['TOTAL_COST', 'MODE_OF_TENDER_CODE', 'FINANCIAL_POWER_CODE',
#        'FINANCIAL_POWER_SERIAL_NO', 'CFA_CODE', 'UO_NO', 'GEM_CONTRACT_NO',
#        'BUDGET_HEAD_CODE', 'BUDGET_HEAD_DESCRIPTION', 'AGAINST_SANCTION_NO',
#        'MINOR_HEAD', 'UNITCODE', 'ESTIMATED_COST', 'DIVISION_NO', 'FIN_POWER',
#        'FIN_POWER_DEMAND_FS', 'BUDGET_HEAD_DESCRIPTION_1', 'CONCURRENCE_BY',
#        'APPROVAL_AMOUNT', 'SUPPLY_ORDER_DATE_Year', 'SUPPLY_ORDER_DATE_Day'],
#       dtype='object')

# %%
# !sudo pip install xgboost
import xgboost
from xgboost import XGBClassifier
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: xgboost in /usr/local/lib/python3.10/dist-packages (1.7.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from xgboost) (1.22.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from xgboost) (1.10.1)

# %%
clf = XGBClassifier(n_estimators=200)

# %%
clf.fit(x_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=200, n_jobs=None, num_parallel_tree=None,
#               objective='multi:softprob', predictor=None, ...)

# %%
y_pred = clf.predict(x_test)

# %%
from sklearn import metrics
print("ACCURACY OF THE MODEL: ", metrics.accuracy_score(y_test, y_pred))
# Out:
# ACCURACY OF THE MODEL:  0.8388780169602087

# %%
from sklearn.metrics import f1_score
score=f1_score(y_test, y_pred, average='macro')
score
# Out:
# 0.8386469404196326

# %%
y_pred = clf.predict(x_train)

# %%
from sklearn import metrics
print("ACCURACY OF THE MODEL: ", metrics.accuracy_score(y_train, y_pred))
# Out:
# ACCURACY OF THE MODEL:  0.9939876957494407

# %%
output=clf.predict(to_predict)

# %%
answer=["0-60","120-150","150-180","60-90","90-120",">180"]

# %%
output
# Out:
# array([2])

# %%
answer[output.item()]
# Out:
# '150-180'
